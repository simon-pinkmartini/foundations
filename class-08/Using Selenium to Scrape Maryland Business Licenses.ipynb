# %% [markdown]
# # Scraping Maryland Business Licenses with Selenium
#
# Maryland has a [great portal](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp) for searching business licenses, but the only problem is you have to check a box in order to get in.
#
# 1. Try to visit [the public search page](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp)
# 2. Get redirected to a "I agree to this" page. Click that you've read the disclaimer, click Enter the Site.
# 3. Click "Search License Records" down at the bottom of the page
# 4. You're now on the search page! From the "Jurisdiction" dropdown, select "Statewide"
# 5. In the "Trade Name" field, type "Vap%" to try to find vape shops
# 6. Click "Next" in the bottom right-hand corner to go to the next page
# 7. Click "Click for detail" to see the details for a specific business license.
#
# That's a lot of stuff! **Let's get to work.**

# %% [markdown]
# ## Preparation
#
# ### When you search for a business license, what URL should Selenium try to visit first?

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
driver = webdriver.Chrome()

# %%
url = "https://jportal.mdcourts.gov/license/index_disclaimer.jsp"

# %%
driver.get(url)

# %% [markdown]
# **It isn't going to work, though! It's going to redirect to that intro page.** You can use *Incognito mode* to go back through the "Check the box, etc" series of pages.
#
# ### How will you identify the checkbox to check it?
#
# Selenium can find elements by:
#
# - name
# - Class
# - ID
# - CSS selector (**ASK ME WHAT THIS IS** if you don't know)
# - XPath (**ASK ME WHAT THIS IS** because you definitely don't know)
# - Link text
# - Partial link text
#
# So in other words, what's unique about this element?
#
# - *TIP: I have a secret awesome way to do this, but you have to ask.*

# %% [markdown]
# ### How will you identify the button to select it, or the form to submit it?
#
# Selenium can submit forms by either
#
# - Selecting the form and using `.submit()`, or
# - Selecting the button and using `.click()`
#
# You only need to be able to get **one, not both.**

# %%
driver.find_element_by_id("checkbox").click()

# %%
driver.find_element_by_xpath('/html/body/table/tbody/tr[7]/td/form/div/input[2]').click()

# %% [markdown]
# ### Once you're on the next page, how will you click the "SEARCH LICENSE RECORDS" link or follow its URL?

# %%
driver.find_element_by_link_text('SEARCH LICENSE RECORDS').click()

# %% [markdown]
# ### Now you're on the form page. How do you pick "Statewide" for the jurisdiction dropdown?

# %%
Select(driver.find_element_by_name('slcJurisdiction')).select_by_visible_text('Statewide')

# %% [markdown]
# ### How do you type "vap%" into the Trade Name field?

# %%
driver.find_element_by_id('txtTradeName').send_keys("vap%")

# %% [markdown]
# ### How do you click the submit button or submit the form?

# %%
driver.find_element_by_tag_name('form').submit()

# %% [markdown]
# ### How can you find and click the 'Next' button on the search results page?

# %%
driver.find_element_by_link_text('Next »').click()

# %% [markdown]
# # Okay, let's scrape!
#
# ### Use Selenium to search for vape shops statewide, and then click through until it reaches the last page.
#
# Don't scrape yet!

# %%
while True:
    try:
        driver.find_element_by_link_text('Next »').click()
    except:
        break

# %% [markdown]
# ### Use Selenium to scrape the first page of search results for vape shops statewide (well, we'll try).
#
# - *TIP: You can find elements/text using Selenium, or use BeautifulSoup with `doc = BeautifulSoup(driver.page_source)`*
#
# I've included some BeautifulSoup code that might be helpful. If you use it, **ask me how I made it.** It's important.

# %%
doc = BeautifulSoup(driver.page_source, "html.parser")

# %%
# IF YOU ARE USING BEAUTIFULSOUP, HERE IS SOME SAMPLE CODE
business_headers = doc.find_all('tr',class_='searchfieldtitle')
# Out:
# <tr class="searchfieldtitle">
# <td class="searchlistnumber">1.</td>
# <td class="searchlistitem"><span class="copybold">VAPE IT STORE II</span></td>
# <td><a href="pbLicenseDetail.jsp?owi=6rq%2BeY63IN0%3D"><img alt="Click for Detail of VAPE IT STORE II" src="images/link_click-detail.gif"/></a></td>
# </tr>

# %%
#SCRAPING ONE PAGE

businesses = []

for header in business_headers:
    
    current = {}
    
    name = header.find_all('td')[1].span.text.strip()
    current["Name"] = name
    print ("Name:", name)
    
    link = ""
    if header.find_all('td')[2].a:
        link = header.find_all('td')[2].a["href"]
    current["Link"] = link
    print ("Link:", link)
    
    rows = header.find_next_siblings('tr')
    
    company = rows[0].find_all('td')[1].text.strip()
    current["Company"] = company
    print ("Company:", company)
    
    adr_1 = rows[1].find_all('td')[1].text.strip()
    adr_2 = rows[2].find_all('td')[1].text.strip()
    current["Adressline_1"] = adr_1
    current["Adressline_2"] = adr_2
    print ("Adress:", adr_1, "|", adr_2)
    
    county = rows[3].find_all('td')[1].text.strip()
    current["County"] = county
    print ("County:", county)
    
    lic_status = rows[0].find_all('td')[2].span.next_sibling.strip()
    current["Lic. Status"] = lic_status
    print ("Lic. Status:", lic_status)
    
    license = rows[1].find_all('td')[2].text
    if license != "":
        license = rows[1].find_all('td')[2].span.next_sibling.strip()
    current["License"] = license    
    print ("License:", license)
    
    issued = rows[2].find_all('td')[2].text
    if issued != "":
        issued = rows[2].find_all('td')[2].span.next_sibling.strip()
    current["Issued"] = issued
    print ("Issued:", issued)
    
    businesses.append(current)
    
    print("----")
# Out:
# Name: VAPE IT STORE II
# Link: pbLicenseDetail.jsp?owi=6rq%2BeY63IN0%3D
# Company: AMIN NARGIS
# Adress: 1015 S SALISBURY BLVD | SALISBURY, MD 21801
# County: Wicomico County
# Lic. Status: Issued
# License: 22173808
# Issued: 4/27/2017
# ----
# Name: VAPE IT STORE I
# Link: pbLicenseDetail.jsp?owi=Z2yBcwi5H0A%3D
# Company: AMIN NARGIS
# Adress: 1724 N SALISBURY BLVD UNIT 2 | SALISBURY, MD 21801
# County: Wicomico County
# Lic. Status: Issued
# License: 22173807
# Issued: 4/27/2017
# ----
# Name: VAPEPAD THE
# Link: pbLicenseDetail.jsp?owi=aoxGKTEKPq4%3D
# Company: ANJ DISTRIBUTIONS LLC
# Adress: 2299 JOHNS HOPKINS ROAD | GAMBRILLS, MD 21054
# County: Anne Arundel County
# Lic. Status: Issued
# License: 02104436
# Issued: 4/05/2017
# ----
# Name: VAPE FROG
# Link: pbLicenseDetail.jsp?owi=cAocC89gtTI%3D
# Company: COX TRADING COMPANY L L C
# Adress: 110 S. PINEY RD | CHESTER, MD 21619
# County: Queen Anne's County
# Lic. Status: Issued
# License: 17165957
# Issued: 5/31/2017
# ----
# Name: VAPE FROG
# Link:
# Company: COX TRADING LLC
# Adress: 346 RITCHIE HIGHWAY | SEVERNA PARK, MD 21146
# County: Anne Arundel County
# Lic. Status: Pending
# License:
# Issued:
# ----
# [{'Name': 'VAPE IT STORE II', 'Link': 'pbLicenseDetail.jsp?owi=6rq%2BeY63IN0%3D', 'Company': 'AMIN NARGIS', 'Adressline_1': '1015 S SALISBURY BLVD', 'Adressline_2': 'SALISBURY, MD 21801', 'County': 'Wicomico County', 'Lic. Status': 'Issued', 'License': '22173808', 'Issued': '4/27/2017'}, {'Name': 'VAPE IT STORE I', 'Link': 'pbLicenseDetail.jsp?owi=Z2yBcwi5H0A%3D', 'Company': 'AMIN NARGIS', 'Adressline_1': '1724 N SALISBURY BLVD UNIT 2', 'Adressline_2': 'SALISBURY, MD 21801', 'County': 'Wicomico County', 'Lic. Status': 'Issued', 'License': '22173807', 'Issued': '4/27/2017'}, {'Name': 'VAPEPAD THE', 'Link': 'pbLicenseDetail.jsp?owi=aoxGKTEKPq4%3D', 'Company': 'ANJ DISTRIBUTIONS LLC', 'Adressline_1': '2299 JOHNS HOPKINS ROAD', 'Adressline_2': 'GAMBRILLS, MD 21054', 'County': 'Anne Arundel County', 'Lic. Status': 'Issued', 'License': '02104436', 'Issued': '4/05/2017'}, {'Name': 'VAPE FROG', 'Link': 'pbLicenseDetail.jsp?owi=cAocC89gtTI%3D', 'Company': 'COX TRADING COMPANY L L C', 'Adressline_1': '110 S. PINEY RD', 'Adressline_2': 'CHESTER, MD 21619', 'County': "Queen Anne's County", 'Lic. Status': 'Issued', 'License': '17165957', 'Issued': '5/31/2017'}, {'Name': 'VAPE FROG', 'Link': '', 'Company': 'COX TRADING LLC', 'Adressline_1': '346 RITCHIE HIGHWAY', 'Adressline_2': 'SEVERNA PARK, MD 21146', 'County': 'Anne Arundel County', 'Lic. Status': 'Pending', 'License': '', 'Issued': ''}]

# %% [markdown]
# ### Save these into `vape-results.csv`

# %%
df = pd.DataFrame(businesses, columns=['Name', 'Link', 'License', 'Lic. Status', 'Issued', 'Company', 'Adressline_1', 'Adressline_2', 'County'])

# %%
df.to_csv("vape-results.csv", index=False)

# %% [markdown]
# ### Open `vape-results.csv` to make sure there aren't any extra weird columns

# %%
df_in = pd.read_csv("vape-results.csv")

# %%
df_in #Looks good!
# Out:
#                Name                                      Link     License  \
# 0  VAPE IT STORE II  pbLicenseDetail.jsp?owi=6rq%2BeY63IN0%3D  22173808.0
# 1   VAPE IT STORE I    pbLicenseDetail.jsp?owi=Z2yBcwi5H0A%3D  22173807.0
# 2       VAPEPAD THE    pbLicenseDetail.jsp?owi=aoxGKTEKPq4%3D   2104436.0
# 3         VAPE FROG    pbLicenseDetail.jsp?owi=cAocC89gtTI%3D  17165957.0
# 4         VAPE FROG                                       NaN         NaN
#
#   Lic. Status     Issued                    Company  \
# 0      Issued  4/27/2017                AMIN NARGIS
# 1      Issued  4/27/2017                AMIN NARGIS
# 2      Issued  4/05/2017      ANJ DISTRIBUTIONS LLC
# 3      Issued  5/31/2017  COX TRADING COMPANY L L C
# 4     Pending        NaN            COX TRADING LLC
#
#                    Adressline_1            Adressline_2               County
# 0         1015 S SALISBURY BLVD     SALISBURY, MD 21801      Wicomico County
# 1  1724 N SALISBURY BLVD UNIT 2     SALISBURY, MD 21801      Wicomico County
# 2       2299 JOHNS HOPKINS ROAD     GAMBRILLS, MD 21054  Anne Arundel County
# 3               110 S. PINEY RD       CHESTER, MD 21619  Queen Anne's County
# 4           346 RITCHIE HIGHWAY  SEVERNA PARK, MD 21146  Anne Arundel County

# %% [markdown]
# ## Use Selenium to scrape ALL pages of results, save the results into `vape-results-all.csv`.

# %%
#bring browser back to the 1st page:
driver.get(url)

# %%
driver.find_element_by_id("checkbox").click()
driver.find_element_by_xpath('/html/body/table/tbody/tr[7]/td/form/div/input[2]').click()

# %%
driver.find_element_by_link_text('SEARCH LICENSE RECORDS').click()

# %%
Select(driver.find_element_by_name('slcJurisdiction')).select_by_visible_text('Statewide')
driver.find_element_by_id('txtTradeName').send_keys("vap%")
driver.find_element_by_tag_name('form').submit()

# %%
#set up the main list container where will will scrape into
businesses = []

# %%
#define a function we will use to scrape data
def scrape():
    
    #get page content into BeautifulSoup
    doc = BeautifulSoup(driver.page_source, "html.parser")
    
    #Create array of data entries
    business_headers = doc.find_all('tr',class_='searchfieldtitle')
    
    #Get the data fields and store in a dictionary
    for header in business_headers:

        current = {}

        name = header.find_all('td')[1].span.text.strip()
        current["Name"] = name

        link = ""
        if header.find_all('td')[2].a:
            link = header.find_all('td')[2].a["href"]
        current["Link"] = link

        rows = header.find_next_siblings('tr')

        company = rows[0].find_all('td')[1].text.strip()
        current["Company"] = company

        adr_1 = rows[1].find_all('td')[1].text.strip()
        adr_2 = rows[2].find_all('td')[1].text.strip()
        current["Adressline_1"] = adr_1
        current["Adressline_2"] = adr_2

        county = rows[3].find_all('td')[1].text.strip()
        current["County"] = county

        lic_status = rows[0].find_all('td')[2].span.next_sibling.strip()
        current["Lic. Status"] = lic_status

        license = rows[1].find_all('td')[2].text
        if license != "":
            license = rows[1].find_all('td')[2].span.next_sibling.strip()
        current["License"] = license    

        issued = rows[2].find_all('td')[2].text
        if issued != "":
            issued = rows[2].find_all('td')[2].span.next_sibling.strip()
        current["Issued"] = issued
        
        businesses.append(current)

# %%
#set up the loop to bring browser through all the pages
while True:
    try:
        scrape()
        driver.find_element_by_link_text('Next »').click()
    except:
        break

# %%
businesses #looks good!
# Out:
# [{'Adressline_1': '1015 S SALISBURY BLVD',
#   'Adressline_2': 'SALISBURY, MD 21801',
#   'Company': 'AMIN NARGIS',
#   'County': 'Wicomico County',
#   'Issued': '4/27/2017',
#   'Lic. Status': 'Issued',
#   'License': '22173808',
#   'Link': 'pbLicenseDetail.jsp?owi=6rq%2BeY63IN0%3D',
#   'Name': 'VAPE IT STORE II'},
#  {'Adressline_1': '1724 N SALISBURY BLVD UNIT 2',
#   'Adressline_2': 'SALISBURY, MD 21801',
#   'Company': 'AMIN NARGIS',
#   'County': 'Wicomico County',
#   'Issued': '4/27/2017',
#   'Lic. Status': 'Issued',
#   'License': '22173807',
#   'Link': 'pbLicenseDetail.jsp?owi=Z2yBcwi5H0A%3D',
#   'Name': 'VAPE IT STORE I'},
#  {'Adressline_1': '2299 JOHNS HOPKINS ROAD',
#   'Adressline_2': 'GAMBRILLS, MD 21054',
#   'Company': 'ANJ DISTRIBUTIONS LLC',
#   'County': 'Anne Arundel County',
#   'Issued': '4/05/2017',
#   'Lic. Status': 'Issued',
#   'License': '02104436',
#   'Link': 'pbLicenseDetail.jsp?owi=aoxGKTEKPq4%3D',
#   'Name': 'VAPEPAD THE'},
#  {'Adressline_1': '110 S. PINEY RD',
#   'Adressline_2': 'CHESTER, MD 21619',
#   'Company': 'COX TRADING COMPANY L L C',
#   'County': "Queen Anne's County",
#   'Issued': '5/31/2017',
#   'Lic. Status': 'Issued',
#   'License': '17165957',
#   'Link': 'pbLicenseDetail.jsp?owi=cAocC89gtTI%3D',
#   'Name': 'VAPE FROG'},
#  {'Adressline_1': '346 RITCHIE HIGHWAY',
#   'Adressline_2': 'SEVERNA PARK, MD 21146',
#   'Company': 'COX TRADING LLC',
#   'County': 'Anne Arundel County',
#   'Issued': '',
#   'Lic. Status': 'Pending',
#   'License': '',
#   'Link': '',
#   'Name': 'VAPE FROG'},
#  {'Adressline_1': '185 MITCHELLS CHANCE RD',
#   'Adressline_2': 'EDGEWATER, MD 21037',
#   'Company': 'DISBROW II EMERSON HARRINGTON',
#   'County': 'Anne Arundel County',
#   'Issued': '4/13/2017',
#   'Lic. Status': 'Issued',
#   'License': '02102408',
#   'Link': 'pbLicenseDetail.jsp?owi=OkOPFZ5CCNo%3D',
#   'Name': 'VAPE LOFT (THE)'},
#  {'Adressline_1': '7104 MINSTREL UNIT #7',
#   'Adressline_2': 'COLUMBIA, MD 21045',
#   'Company': 'DISCOUNT TOBACCO ESSEX LLC',
#   'County': 'Howard County',
#   'Issued': '5/19/2017',
#   'Lic. Status': 'Issued',
#   'License': '13141786',
#   'Link': 'pbLicenseDetail.jsp?owi=CX8%2BVN1zzbs%3D',
#   'Name': 'VAPE N CIGAR'},
#  {'Adressline_1': '330 ONE FORTY VILLAGE ROAD',
#   'Adressline_2': 'WESTMINSTER, MD 21157',
#   'Company': 'FAIRGROUND VILLAGE LLC',
#   'County': 'Carroll County',
#   'Issued': '4/21/2017',
#   'Lic. Status': 'Issued',
#   'License': '06126253',
#   'Link': 'pbLicenseDetail.jsp?owi=GOHsZYgZMmw%3D',
#   'Name': 'VAPE DOJO'},
#  {'Adressline_1': '29890 THREE NOTCH ROAD',
#   'Adressline_2': 'CHARLOTTE HALL, MD 20622',
#   'Company': 'GRIMM JENNIFER',
#   'County': "St. Mary's County",
#   'Issued': '',
#   'Lic. Status': 'Pending',
#   'License': '',
#   'Link': '',
#   'Name': 'VAPE HAVEN'},
#  {'Adressline_1': '356 ROMANCOKE ROAD',
#   'Adressline_2': 'STEVENSVILLE, MD 21666',
#   'Company': 'HUTCH VAPES LLC',
#   'County': "Queen Anne's County",
#   'Issued': '4/13/2017',
#   'Lic. Status': 'Issued',
#   'License': '17166688',
#   'Link': 'pbLicenseDetail.jsp?owi=JaBhKUOOJMM%3D',
#   'Name': 'VAPE BIRD'},
#  {'Adressline_1': '110 S PINEY ROAD  STE 106',
#   'Adressline_2': 'CHESTER, MD 21619',
#   'Company': 'HUTCHINS COX LLP',
#   'County': "Queen Anne's County",
#   'Issued': '',
#   'Lic. Status': 'Pending',
#   'License': '',
#   'Link': '',
#   'Name': 'VAPE FROG'},
#  {'Adressline_1': '28943 THREE NOTCH ROAD',
#   'Adressline_2': 'MECHANICSVILLE, MD 20659',
#   'Company': 'JAMESON WILLIAM',
#   'County': "St. Mary's County",
#   'Issued': '5/17/2017',
#   'Lic. Status': 'Issued',
#   'License': '18167503',
#   'Link': 'pbLicenseDetail.jsp?owi=mBh71wHjygQ%3D',
#   'Name': 'VAPORS LOUNGE'},
#  {'Adressline_1': '6843 CRAIN HIGHWAY',
#   'Adressline_2': 'LA PLATA, MD 20646',
#   'Company': 'JAMESON WILLIAM E',
#   'County': 'Charles County',
#   'Issued': '',
#   'Lic. Status': 'Pending',
#   'License': '',
#   'Link': '',
#   'Name': 'VAPORS LOUNGE'},
#  {'Adressline_1': '6321 OLD BRANCH AVE',
#   'Adressline_2': 'CAMP SPRINGS, MD 20748',
#   'Company': 'JEFFERS MICHAEL',
#   'County': "St. Mary's County",
#   'Issued': '',
#   'Lic. Status': 'Pending',
#   'License': '',
#   'Link': '',
#   'Name': 'VAPIST MD'},
#  {'Adressline_1': '6321 OLD BRANCH AVE',
#   'Adressline_2': 'CAMP SPRINGS, MD 20748',
#   'Company': 'JEFFERS MICHAEL W',
#   'County': "Prince George's County",
#   'Issued': '',
#   'Lic. Status': 'Pending',
#   'License': '',
#   'Link': '',
#   'Name': 'VAPIST MD LLC'},
#  {'Adressline_1': '7954 B AND A BLVD',
#   'Adressline_2': 'GLEN BURNIE, MD 21060',
#   'Company': 'SHIN JENNY Y',
#   'County': 'Anne Arundel County',
#   'Issued': '',
#   'Lic. Status': 'Pending',
#   'License': '',
#   'Link': '',
#   'Name': 'VAPERTETMD'},
#  {'Adressline_1': '6325 WASHINGTON BLVD',
#   'Adressline_2': 'ELKRIDGE, MD 21075',
#   'Company': 'SHIN JENNY YOUNG',
#   'County': 'Howard County',
#   'Issued': '',
#   'Lic. Status': 'Pending',
#   'License': '',
#   'Link': '',
#   'Name': 'VAPERTEKMD'},
#  {'Adressline_1': '3203 NORTH POINT RD',
#   'Adressline_2': 'BALTIMORE, MD 21222',
#   'Company': 'TAYLOR TRAVIS',
#   'County': 'Baltimore County',
#   'Issued': '',
#   'Lic. Status': 'Pending',
#   'License': '',
#   'Link': '',
#   'Name': 'VAPORIOT'},
#  {'Adressline_1': '519 LINDEN AVENUE UNIT 6',
#   'Adressline_2': 'POCOMOKE CITY, MD 21851',
#   'Company': 'TRUE ENTERPRISE INC',
#   'County': 'Worcester County',
#   'Issued': '5/05/2017',
#   'Lic. Status': 'Issued',
#   'License': '23178140',
#   'Link': 'pbLicenseDetail.jsp?owi=xsSew8A55nc%3D',
#   'Name': 'VAPE PLUS'},
#  {'Adressline_1': '16521 S FREDERICK AVE',
#   'Adressline_2': 'GAITHERSBURG, MD 20877',
#   'Company': 'VAPE  SOCIAL  LLC',
#   'County': 'Montgomery County',
#   'Issued': '4/18/2017',
#   'Lic. Status': 'Issued',
#   'License': '15155429',
#   'Link': 'pbLicenseDetail.jsp?owi=NltIXx5zi0U%3D',
#   'Name': 'VAPE  SOCIAL'},
#  {'Adressline_1': '2070 CRAIN HIGHWAY  UNIT F',
#   'Adressline_2': 'WALDORF, MD 20601',
#   'Company': 'VAPE JUNGLE LLC',
#   'County': 'Charles County',
#   'Issued': '3/31/2017',
#   'Lic. Status': 'Issued',
#   'License': '08131285',
#   'Link': 'pbLicenseDetail.jsp?owi=%2Fxfj3l%2BD1Zc%3D',
#   'Name': 'VAPE JUNGLE'},
#  {'Adressline_1': '4130 E JOPPA RD UNIT 109',
#   'Adressline_2': 'NOTTINGHAM, MD 21236',
#   'Company': 'VAPE TIME LLC',
#   'County': 'Baltimore County',
#   'Issued': '',
#   'Lic. Status': 'Pending',
#   'License': '',
#   'Link': '',
#   'Name': 'VAPE TIME'},
#  {'Adressline_1': '11110 MALL CIRCLE',
#   'Adressline_2': 'WALDORF, MD 20603',
#   'Company': 'VAPEBAR EXPRESS LLC',
#   'County': 'Charles County',
#   'Issued': '',
#   'Lic. Status': 'Pending',
#   'License': '',
#   'Link': '',
#   'Name': 'VAPEBAR EXPESS'},
#  {'Adressline_1': '3524 CRAIN HWY',
#   'Adressline_2': 'BOWIE, MD 20716',
#   'Company': 'VAPOR 99 LLC',
#   'County': "Prince George's County",
#   'Issued': '5/03/2017',
#   'Lic. Status': 'Issued',
#   'License': '16165362',
#   'Link': 'pbLicenseDetail.jsp?owi=qdsVkkv%2FPSU%3D',
#   'Name': 'VAPOR 99'},
#  {'Adressline_1': '8117 OCEAN GATEWAY UNIT #4',
#   'Adressline_2': 'EASTON, MD 21601',
#   'Company': 'VAPOR ALLEY LLC',
#   'County': 'Talbot County',
#   'Issued': '5/10/2017',
#   'Lic. Status': 'Issued',
#   'License': '20170900',
#   'Link': 'pbLicenseDetail.jsp?owi=wUCurzIplVA%3D',
#   'Name': 'VAPOR ALLEY'},
#  {'Adressline_1': '11717 OLD NATIONAL PIKE',
#   'Adressline_2': 'NEW MARKET, MD 21774',
#   'Company': 'VAPOR EMPORIUM MD LLC',
#   'County': 'Frederick County',
#   'Issued': '4/14/2017',
#   'Lic. Status': 'Issued',
#   'License': '10135432',
#   'Link': 'pbLicenseDetail.jsp?owi=jaK1ZIC6pfI%3D',
#   'Name': 'VAPOR EMPORIUM'},
#  {'Adressline_1': '1913 LANSDOWNE ROAD SUITE E',
#   'Adressline_2': 'BALTIMORE, MD 21227',
#   'Company': 'VAPOR VILLA CORP',
#   'County': 'Baltimore County',
#   'Issued': '4/12/2017',
#   'Lic. Status': 'Issued',
#   'License': '03121958',
#   'Link': 'pbLicenseDetail.jsp?owi=iff2hRM6LrI%3D',
#   'Name': 'VAPOR VILLA'},
#  {'Adressline_1': '730 FREDERICK ROAD',
#   'Adressline_2': 'CATONSVILLE, MD 21228',
#   'Company': 'VAPOR VILLA CORP',
#   'County': 'Baltimore County',
#   'Issued': '4/12/2017',
#   'Lic. Status': 'Issued',
#   'License': '03121959',
#   'Link': 'pbLicenseDetail.jsp?owi=TZ%2FL56GqgUM%3D',
#   'Name': 'VAPOR VILLA'},
#  {'Adressline_1': '138 N BOND STREET',
#   'Adressline_2': 'BEL AIR, MD 21014',
#   'Company': 'WALKER TRADING CO INC',
#   'County': 'Harford County',
#   'Issued': '4/03/2017',
#   'Lic. Status': 'Issued',
#   'License': '12140135',
#   'Link': 'pbLicenseDetail.jsp?owi=jsqLonPRhxQ%3D',
#   'Name': 'VAPE DOJO'},
#  {'Adressline_1': '3570 SAINT JOHNS LANE, SUITE 109',
#   'Adressline_2': 'ELLICOTT CITY, MD 21042',
#   'Company': 'WALKER TRADING COMPANY INC',
#   'County': 'Howard County',
#   'Issued': '3/27/2017',
#   'Lic. Status': 'Issued',
#   'License': '13144108',
#   'Link': 'pbLicenseDetail.jsp?owi=Iv4VDrHMz0E%3D',
#   'Name': 'VAPE DOJO'},
#  {'Adressline_1': '11600 CROSSROAD CIR  STE E',
#   'Adressline_2': 'BALTIMORE, MD 21220',
#   'Company': 'WALKER TRADING COMPANY INC',
#   'County': 'Baltimore County',
#   'Issued': '',
#   'Lic. Status': 'Pending',
#   'License': '',
#   'Link': '',
#   'Name': 'VAPE DOJO'},
#  {'Adressline_1': '3315 PLAZA WAY',
#   'Adressline_2': 'WALDORF, MD 20603',
#   'Company': 'YARKHOUSE EMPIRE INC',
#   'County': 'Charles County',
#   'Issued': '',
#   'Lic. Status': 'Pending',
#   'License': '',
#   'Link': '',
#   'Name': 'VAPEZ YARDHOUSE'}]

# %%
#store the dictionary in a DataFrame
df = pd.DataFrame(businesses, columns=['Name', 'Link', 'License', 'Lic. Status', 'Issued', 'Company', 'Adressline_1', 'Adressline_2', 'County'])

# %%
#write the DataFrame into a csv-File
df.to_csv("vape-results.csv", index=False)

# %%
#Open the csv-File to check
df_in = pd.read_csv("vape-results.csv")
df_in #looks good!
# Out:
#                 Name                                        Link     License  \
# 0   VAPE IT STORE II    pbLicenseDetail.jsp?owi=6rq%2BeY63IN0%3D  22173808.0
# 1    VAPE IT STORE I      pbLicenseDetail.jsp?owi=Z2yBcwi5H0A%3D  22173807.0
# 2        VAPEPAD THE      pbLicenseDetail.jsp?owi=aoxGKTEKPq4%3D   2104436.0
# 3          VAPE FROG      pbLicenseDetail.jsp?owi=cAocC89gtTI%3D  17165957.0
# 4          VAPE FROG                                         NaN         NaN
# 5    VAPE LOFT (THE)      pbLicenseDetail.jsp?owi=OkOPFZ5CCNo%3D   2102408.0
# 6       VAPE N CIGAR    pbLicenseDetail.jsp?owi=CX8%2BVN1zzbs%3D  13141786.0
# 7          VAPE DOJO      pbLicenseDetail.jsp?owi=GOHsZYgZMmw%3D   6126253.0
# 8         VAPE HAVEN                                         NaN         NaN
# 9          VAPE BIRD      pbLicenseDetail.jsp?owi=JaBhKUOOJMM%3D  17166688.0
# 10         VAPE FROG                                         NaN         NaN
# 11     VAPORS LOUNGE      pbLicenseDetail.jsp?owi=mBh71wHjygQ%3D  18167503.0
# 12     VAPORS LOUNGE                                         NaN         NaN
# 13         VAPIST MD                                         NaN         NaN
# 14     VAPIST MD LLC                                         NaN         NaN
# 15        VAPERTETMD                                         NaN         NaN
# 16        VAPERTEKMD                                         NaN         NaN
# 17          VAPORIOT                                         NaN         NaN
# 18         VAPE PLUS      pbLicenseDetail.jsp?owi=xsSew8A55nc%3D  23178140.0
# 19      VAPE  SOCIAL      pbLicenseDetail.jsp?owi=NltIXx5zi0U%3D  15155429.0
# 20       VAPE JUNGLE  pbLicenseDetail.jsp?owi=%2Fxfj3l%2BD1Zc%3D   8131285.0
# 21         VAPE TIME                                         NaN         NaN
# 22    VAPEBAR EXPESS                                         NaN         NaN
# 23          VAPOR 99    pbLicenseDetail.jsp?owi=qdsVkkv%2FPSU%3D  16165362.0
# 24       VAPOR ALLEY      pbLicenseDetail.jsp?owi=wUCurzIplVA%3D  20170900.0
# 25    VAPOR EMPORIUM      pbLicenseDetail.jsp?owi=jaK1ZIC6pfI%3D  10135432.0
# 26       VAPOR VILLA      pbLicenseDetail.jsp?owi=iff2hRM6LrI%3D   3121958.0
# 27       VAPOR VILLA    pbLicenseDetail.jsp?owi=TZ%2FL56GqgUM%3D   3121959.0
# 28         VAPE DOJO      pbLicenseDetail.jsp?owi=jsqLonPRhxQ%3D  12140135.0
# 29         VAPE DOJO      pbLicenseDetail.jsp?owi=Iv4VDrHMz0E%3D  13144108.0
# 30         VAPE DOJO                                         NaN         NaN
# 31   VAPEZ YARDHOUSE                                         NaN         NaN
#
#    Lic. Status     Issued                        Company  \
# 0       Issued  4/27/2017                    AMIN NARGIS
# 1       Issued  4/27/2017                    AMIN NARGIS
# 2       Issued  4/05/2017          ANJ DISTRIBUTIONS LLC
# 3       Issued  5/31/2017      COX TRADING COMPANY L L C
# 4      Pending        NaN                COX TRADING LLC
# 5       Issued  4/13/2017  DISBROW II EMERSON HARRINGTON
# 6       Issued  5/19/2017     DISCOUNT TOBACCO ESSEX LLC
# 7       Issued  4/21/2017         FAIRGROUND VILLAGE LLC
# 8      Pending        NaN                 GRIMM JENNIFER
# 9       Issued  4/13/2017                HUTCH VAPES LLC
# 10     Pending        NaN               HUTCHINS COX LLP
# 11      Issued  5/17/2017                JAMESON WILLIAM
# 12     Pending        NaN              JAMESON WILLIAM E
# 13     Pending        NaN                JEFFERS MICHAEL
# 14     Pending        NaN              JEFFERS MICHAEL W
# 15     Pending        NaN                   SHIN JENNY Y
# 16     Pending        NaN               SHIN JENNY YOUNG
# 17     Pending        NaN                  TAYLOR TRAVIS
# 18      Issued  5/05/2017            TRUE ENTERPRISE INC
# 19      Issued  4/18/2017              VAPE  SOCIAL  LLC
# 20      Issued  3/31/2017                VAPE JUNGLE LLC
# 21     Pending        NaN                  VAPE TIME LLC
# 22     Pending        NaN            VAPEBAR EXPRESS LLC
# 23      Issued  5/03/2017                   VAPOR 99 LLC
# 24      Issued  5/10/2017                VAPOR ALLEY LLC
# 25      Issued  4/14/2017          VAPOR EMPORIUM MD LLC
# 26      Issued  4/12/2017               VAPOR VILLA CORP
# 27      Issued  4/12/2017               VAPOR VILLA CORP
# 28      Issued  4/03/2017          WALKER TRADING CO INC
# 29      Issued  3/27/2017     WALKER TRADING COMPANY INC
# 30     Pending        NaN     WALKER TRADING COMPANY INC
# 31     Pending        NaN           YARKHOUSE EMPIRE INC
#
#                         Adressline_1              Adressline_2  \
# 0              1015 S SALISBURY BLVD       SALISBURY, MD 21801
# 1       1724 N SALISBURY BLVD UNIT 2       SALISBURY, MD 21801
# 2            2299 JOHNS HOPKINS ROAD       GAMBRILLS, MD 21054
# 3                    110 S. PINEY RD         CHESTER, MD 21619
# 4                346 RITCHIE HIGHWAY    SEVERNA PARK, MD 21146
# 5            185 MITCHELLS CHANCE RD       EDGEWATER, MD 21037
# 6              7104 MINSTREL UNIT #7        COLUMBIA, MD 21045
# 7         330 ONE FORTY VILLAGE ROAD     WESTMINSTER, MD 21157
# 8             29890 THREE NOTCH ROAD  CHARLOTTE HALL, MD 20622
# 9                 356 ROMANCOKE ROAD    STEVENSVILLE, MD 21666
# 10         110 S PINEY ROAD  STE 106         CHESTER, MD 21619
# 11            28943 THREE NOTCH ROAD  MECHANICSVILLE, MD 20659
# 12                6843 CRAIN HIGHWAY        LA PLATA, MD 20646
# 13               6321 OLD BRANCH AVE    CAMP SPRINGS, MD 20748
# 14               6321 OLD BRANCH AVE    CAMP SPRINGS, MD 20748
# 15                 7954 B AND A BLVD     GLEN BURNIE, MD 21060
# 16              6325 WASHINGTON BLVD        ELKRIDGE, MD 21075
# 17               3203 NORTH POINT RD       BALTIMORE, MD 21222
# 18          519 LINDEN AVENUE UNIT 6   POCOMOKE CITY, MD 21851
# 19             16521 S FREDERICK AVE    GAITHERSBURG, MD 20877
# 20        2070 CRAIN HIGHWAY  UNIT F         WALDORF, MD 20601
# 21          4130 E JOPPA RD UNIT 109      NOTTINGHAM, MD 21236
# 22                 11110 MALL CIRCLE         WALDORF, MD 20603
# 23                    3524 CRAIN HWY           BOWIE, MD 20716
# 24        8117 OCEAN GATEWAY UNIT #4          EASTON, MD 21601
# 25           11717 OLD NATIONAL PIKE      NEW MARKET, MD 21774
# 26       1913 LANSDOWNE ROAD SUITE E       BALTIMORE, MD 21227
# 27                730 FREDERICK ROAD     CATONSVILLE, MD 21228
# 28                 138 N BOND STREET         BEL AIR, MD 21014
# 29  3570 SAINT JOHNS LANE, SUITE 109   ELLICOTT CITY, MD 21042
# 30        11600 CROSSROAD CIR  STE E       BALTIMORE, MD 21220
# 31                    3315 PLAZA WAY         WALDORF, MD 20603
#
#                     County
# 0          Wicomico County
# 1          Wicomico County
# 2      Anne Arundel County
# 3      Queen Anne's County
# 4      Anne Arundel County
# 5      Anne Arundel County
# 6            Howard County
# 7           Carroll County
# 8        St. Mary's County
# 9      Queen Anne's County
# 10     Queen Anne's County
# 11       St. Mary's County
# 12          Charles County
# 13       St. Mary's County
# 14  Prince George's County
# 15     Anne Arundel County
# 16           Howard County
# 17        Baltimore County
# 18        Worcester County
# 19       Montgomery County
# 20          Charles County
# 21        Baltimore County
# 22          Charles County
# 23  Prince George's County
# 24           Talbot County
# 25        Frederick County
# 26        Baltimore County
# 27        Baltimore County
# 28          Harford County
# 29           Howard County
# 30        Baltimore County
# 31          Charles County
