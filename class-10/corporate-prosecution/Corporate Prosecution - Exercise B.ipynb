# %% [markdown]
# # Corporate Prosecution - Exercise B
#
# #### Summary
#
# Looking at corporate prosecutions over time, and the possible assignment of a compliance officer.
#
# #### Files
#
# - cpr-data.xls, "detailed information about every federal organizational prosecution since 2001, as well as deferred and non-prosecution agreements with organizations since 1990"
#
# #### Data Source(s)
#
# The UVA School of Law publishees a [Corpoate Prosecution Registry](http://lib.law.virginia.edu/Garrett/corporate-prosecution-registry/about.html)
#
# > The goal of this Corporate Prosecutions Registry is to provide comprehensive and up-to-date information on federal organizational prosecutions in the United States, so that we can better understand how corporate prosecutions are brought and resolved. We include detailed information about every federal organizational prosecution since 2001, as well as deferred and non-prosecution agreements with organizations since 1990.
#
# [Corpoate Prosecution Registry](http://lib.law.virginia.edu/Garrett/corporate-prosecution-registry/about.html)
#
# #### Skills
#
# - Working with CSV files
# - Counting and summarizing columns
# - Searching with strings
# - Extracting with strings

# %% [markdown]
# # Read in `cpr-data.csv`

# %%
# %matplotlib inline

# %%
import pandas as pd 

df = pd.read_csv("cpr-data.csv")
df.head()
# Out:
#    REC_ID                                 COMPANY DISPOSITION_TYPE  \
# 0     138  1st Union Transfer and Telegraph, Inc.             plea
# 1     139                3D Poultry Loading, Inc.             plea
# 2    2529                         3rd & Bell, LLC             plea
# 3     822                          41 Market Inc.             plea
# 4     140                            45,000, Inc.             plea
#
#                          PRIMARY_CRIME_CODE SWISS_BANK_PROGRAM  \
# 0                          Money Laundering                NaN
# 1                               Immigration                NaN
# 2                               Immigration                NaN
# 3  Controlled substances / Drugs / Meth Act                NaN
# 4                             Environmental                NaN
#
#                           USAO        COUNTRY FINANCIAL_INSTITUTION  \
# 0  Virginia - Eastern District  United States                   Yes
# 1  Arkansas - Western District  United States                    No
# 2                      Arizona  United States                    No
# 3  Georgia - Northern District  United States                    No
# 4  Louisiana - Middle District  United States                    No
#
#                                       CASE_NAME        CASE_ID  ...    \
# 0                     USA v. 1st Union Transfer  4:03-cr-00024  ...
# 1                     USA v. 3D Poultry Loading  2:04-cr-20061  ...
# 2  USA v. Danny's Management Services LLC et al  2:13-cr-01143  ...
# 3                         USA v. 41 Market Inc.  4:06-cr-00023  ...
# 4                              USA v. 45000 Inc  3:04-cr-00180  ...
#
#   PRIVACY_WAIVER REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE  \
# 0            NaN                                            NaN
# 1            NaN                                            NaN
# 2            NaN                                            NaN
# 3            NaN                                            NaN
# 4            NaN                                            NaN
#
#   REGULATORY_FINE REG_AGENCY STATEMENT_OF_FACTS TOTAL_REGULATORY  \
# 0             NaN        NaN                NaN              NaN
# 1             NaN        NaN                NaN              NaN
# 2             NaN        NaN                NaN              NaN
# 3             NaN        NaN                NaN              NaN
# 4             NaN        NaN                NaN              NaN
#
#    UNRELATED_TERMS  AGMT_YEAR  SOURCE  NOTES
# 0              NaN     2003.0   PACER    NaN
# 1              NaN     2005.0   PACER    NaN
# 2              NaN     2014.0   PACER    NaN
# 3              NaN     2006.0   PACER    NaN
# 4              NaN     2005.0   PACER    NaN
#
# [5 rows x 56 columns]

# %% [markdown]
# ### Check that your dataframe has 3038 rows and 56 columns.

# %%
df.shape
# Out:
# (3038, 56)

# %% [markdown]
# ### List the columns and their data types

# %%
df.dtypes
# Out:
# REC_ID                                                                      int64
# COMPANY                                                                    object
# DISPOSITION_TYPE                                                           object
# PRIMARY_CRIME_CODE                                                         object
# SWISS_BANK_PROGRAM                                                         object
# USAO                                                                       object
# COUNTRY                                                                    object
# FINANCIAL_INSTITUTION                                                      object
# CASE_NAME                                                                  object
# CASE_ID                                                                    object
# DOCKET_NO                                                                  object
# DATE                                                                       object
# JUDGMENT_DATE                                                              object
# PLEA_DATE                                                                  object
# TICKER                                                                     object
# US_PUBLIC_CO                                                               object
# ADDITIONAL_REGULATORY_FINE_OR_PAYMENT                                     float64
# COMMUNITY_SERVICE_OR_OTHER                                                float64
# FINE                                                                      float64
# FORFEITURE_DISGORGEMENT                                                   float64
# PROBATION_LENGTH                                                          float64
# RESTITUTION                                                               float64
# TOTAL_PAYMENT                                                               int64
# ACCEPTS_RESPONSIBILITY                                                     object
# AGREEMENT_REQUIRED_NEW_POSITIONS                                           object
# AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS                             object
# CITATION_AND_DESCRIPTION                                                   object
# CIVIL_JUDGMENT_OR_SETTLEMENT                                               object
# COMPLIANCE_PROGRAM_DESCRIPTION                                             object
# COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT                                   object
# COMPLIANCE_REQUIRED_BY_REGULATORS                                          object
# CRIME_DESC                                                                 object
# DESCRIPTION_OF_PAYMENTS                                                    object
# DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY     object
# DOJ_CAN_UNILATERALLY_TERMINATE                                             object
# FINE_CALCULATION_INCLUDED                                                  object
# FINE_DESCRIPTION                                                           object
# INDEP_MONITOR_REQUIRED                                                     object
# MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE                                 object
# OTHER_AGREEMENT                                                            object
# OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES                                object
# OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED                            object
# PARALLEL_CIVIL_SUIT                                                        object
# PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR                             object
# PRE_AGREEMENT_COMPLIANCE                                                   object
# PRE_AGREEMENT_COMPLIANCE_DESCRIPTION                                       object
# PRIVACY_WAIVER                                                             object
# REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE                            float64
# REGULATORY_FINE                                                           float64
# REG_AGENCY                                                                 object
# STATEMENT_OF_FACTS                                                         object
# TOTAL_REGULATORY                                                          float64
# UNRELATED_TERMS                                                            object
# AGMT_YEAR                                                                 float64
# SOURCE                                                                     object
# NOTES                                                                      object
# dtype: object

# %% [markdown]
# ### What do the following columns mean?
#
# - PRIMARY_CRIME_CODE: A list of crime types (eg "Accounting Fraud", "Antitrust", etc).
# - DISPOSITION_TYPE: The "outcome" of the process (was it resolved in court or out of court).
# - AGREEMENT_TYPE: What kind of "out of court" agreement was found
# - COUNTRY: Country in which the entity was incorporated.
# - FINE: Amount of fine in U.S. dollars.
# - TOTAL_PAYMENT: Sum of all monetary penalties (fines, and other payments)
# - USAO: Which Attorney Office was involved
# - PROBATION_LENGTH: Length of probation in months.
# - AGREEMENT_REQUIRED_NEW_POSITIONS: If a firm has to install new compliance officers
# - INDEP_MONITOR_REQUIRED: If a firm has to install an independent monitor

# %% [markdown]
# # Customizing the display in pandas
#
# See how the middle of the table has a `...`? Let's fix that.
#
# ## How do you see the number of columns pandas will display?

# %%
pd.options.display.max_columns
# Out:
# 50

# %% [markdown]
# ## Set pandas to display 65 columns

# %%
pd.options.display.max_columns = 65
#OR
pd.set_option("display.max_columns", 65)

# %% [markdown]
# ## How do you see the number of rows pandas will display? Then, set it to display 100 rows at a time.
#
# What does "the number rows pandas will display" actually mean?

# %%
pd.options.display.max_rows
# Out:
# 100

# %%
pd.options.display.max_rows = 100

# %% [markdown]
# ## Describe the TOTAL_PAYMENT column to me numerically - maxes, mins, averages.
#
# Do this in **one line.**

# %%
df.TOTAL_PAYMENT.describe()
# Out:
# count           3,038
# mean       22,842,732
# std       155,697,740
# min                 0
# 25%            21,892
# 50%           200,000
# 75%         2,100,000
# max     4,486,800,000
# Name: TOTAL_PAYMENT, dtype: float64

# %% [markdown]
# ### Oh that's ugly ugly ugly. Set pandas to format floats with 2 decimal points, we probably don't need to be more specific than that. Oh, and tell it to use a `,` in the thousands position!
#
# I'm just going to leave [this here](http://infohost.nmt.edu/~shipman/doc/python27/web/new-str-format.html) for reference. You should definitely come up and ask on the board, though.

# %%
pd.set_option("display.float_format", "{:,.0f}".format)

# %% [markdown]
# ## Look at the fine and the forfeiture disgorgement for the first two rows. Pretty nice!

# %%
df.head(2)
# Out:
#    REC_ID                                 COMPANY DISPOSITION_TYPE  \
# 0     138  1st Union Transfer and Telegraph, Inc.             plea
# 1     139                3D Poultry Loading, Inc.             plea
#
#   PRIMARY_CRIME_CODE SWISS_BANK_PROGRAM                         USAO  \
# 0   Money Laundering                NaN  Virginia - Eastern District
# 1        Immigration                NaN  Arkansas - Western District
#
#          COUNTRY FINANCIAL_INSTITUTION                  CASE_NAME  \
# 0  United States                   Yes  USA v. 1st Union Transfer
# 1  United States                    No  USA v. 3D Poultry Loading
#
#          CASE_ID DOCKET_NO        DATE JUDGMENT_DATE   PLEA_DATE TICKER  \
# 0  4:03-cr-00024         8  2003-06-17    2003-06-17  2003-02-28    NaN
# 1  2:04-cr-20061         7  2005-01-25    2005-01-25  2004-09-30    NaN
#
#   US_PUBLIC_CO  ADDITIONAL_REGULATORY_FINE_OR_PAYMENT  \
# 0           No                                    nan
# 1           No                                    nan
#
#    COMMUNITY_SERVICE_OR_OTHER   FINE  FORFEITURE_DISGORGEMENT  \
# 0                         nan      0                  272,734
# 1                         nan 24,000                      nan
#
#    PROBATION_LENGTH  RESTITUTION  TOTAL_PAYMENT ACCEPTS_RESPONSIBILITY  \
# 0                12          nan         272734                    NaN
# 1                36          nan          24000                    NaN
#
#   AGREEMENT_REQUIRED_NEW_POSITIONS  \
# 0                              NaN
# 1                              NaN
#
#   AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS CITATION_AND_DESCRIPTION  \
# 0                                            NaN                      NaN
# 1                                            NaN                      NaN
#
#   CIVIL_JUDGMENT_OR_SETTLEMENT COMPLIANCE_PROGRAM_DESCRIPTION  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
#
#   COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT COMPLIANCE_REQUIRED_BY_REGULATORS  \
# 0                                      NaN                               NaN
# 1                                      NaN                               NaN
#
#   CRIME_DESC DESCRIPTION_OF_PAYMENTS  \
# 0        NaN                     NaN
# 1        NaN                     NaN
#
#   DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY  \
# 0                                                NaN
# 1                                                NaN
#
#   DOJ_CAN_UNILATERALLY_TERMINATE FINE_CALCULATION_INCLUDED FINE_DESCRIPTION  \
# 0                            NaN                       NaN              NaN
# 1                            NaN                       NaN              NaN
#
#   INDEP_MONITOR_REQUIRED MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE  \
# 0                    NaN                                        NaN
# 1                    NaN                                        NaN
#
#   OTHER_AGREEMENT OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
#
#   OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED PARALLEL_CIVIL_SUIT  \
# 0                                             NaN                 NaN
# 1                                             NaN                 NaN
#
#   PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR PRE_AGREEMENT_COMPLIANCE  \
# 0                                            NaN                      NaN
# 1                                            NaN                      NaN
#
#   PRE_AGREEMENT_COMPLIANCE_DESCRIPTION PRIVACY_WAIVER  \
# 0                                  NaN            NaN
# 1                                  NaN            NaN
#
#    REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE  REGULATORY_FINE REG_AGENCY  \
# 0                                             nan              nan        NaN
# 1                                             nan              nan        NaN
#
#   STATEMENT_OF_FACTS  TOTAL_REGULATORY UNRELATED_TERMS  AGMT_YEAR SOURCE NOTES
# 0                NaN               nan             NaN      2,003  PACER   NaN
# 1                NaN               nan             NaN      2,005  PACER   NaN

# %% [markdown]
# # A little summarizing

# %% [markdown]
# ## How many of cases actually went to trial? How did most of these cases arrive at a decision?

# %%
df_disp = df.DISPOSITION_TYPE.value_counts()
df_disp
# Out:
# plea               2565
# NP                  266
# DP                  201
# trial convicton       2
# dismissal             2
# declination           2
# Name: DISPOSITION_TYPE, dtype: int64

# %%
df_disp[df_disp.index.isin(["plea", "NP", "DP"])]
# Out:
# plea    2565
# NP       266
# DP       201
# Name: DISPOSITION_TYPE, dtype: int64

# %% [markdown]
# ### Graph the previous answer, with the longest bar on top

# %%
df_disp[df_disp.index.isin(["plea", "NP", "DP"])].sort_values().plot(kind="barh")

# %% [markdown]
# ## What's the distribution of total payments look like?

# %%
df.TOTAL_PAYMENT.describe()
# Out:
# count           3,038
# mean       22,842,732
# std       155,697,740
# min                 0
# 25%            21,892
# 50%           200,000
# 75%         2,100,000
# max     4,486,800,000
# Name: TOTAL_PAYMENT, dtype: float64

# %%
df.TOTAL_PAYMENT.hist(bins=100, figsize=(15,5))

# %% [markdown]
# ## Sort by total payments, descending

# %%
df.TOTAL_PAYMENT.sort_values(ascending=False).head(10)
# Out:
# 307     4486800000
# 309     4000000000
# 2913    2800000000
# 1000    2003000000
# 753     1803488986
# 1454    1700000000
# 2167    1300000000
# 1238    1256000000
# 2760    1200000000
# 1168     999999400
# Name: TOTAL_PAYMENT, dtype: int64

# %% [markdown]
# # Column selection
#
# We wanted to view all of those rows, but honestly that's a little silly. **We can't actually see the data we want!** Let's just select the ones we care about.
#
# ## Create a new dataframe that only includes the company name, disposition type, total payment, and date.

# %%
df_new = df[['COMPANY','DISPOSITION_TYPE','TOTAL_PAYMENT','DATE']]
df_new
# Out:
#                                                 COMPANY DISPOSITION_TYPE  \
# 0                1st Union Transfer and Telegraph, Inc.             plea
# 1                              3D Poultry Loading, Inc.             plea
# 2                                       3rd & Bell, LLC             plea
# 3                                        41 Market Inc.             plea
# 4                                          45,000, Inc.             plea
# 5                                       4628 Group Inc.             plea
# 6                                         70 North, LLC             plea
# 7                                     806 Trading Corp.             plea
# 8                               83rd & Union Hills, LLC             plea
# 9                                      84th & Bell, LLC             plea
# 10                                     A & G Coal Corp.             plea
# 11                           A B & J Coal Company, Inc.             plea
# 12                           A J & J Thornton Oil, Inc.             plea
# 13                     A&L Cesspool Service Corporation             plea
# 14                               A-1 Barrel Company LLC             plea
# 15                                       A-1 Homes, LLC             plea
# 16                      A.E. Nomikos Shipping Inv. Ltd.             plea
# 17                               A.J.R. Publishing Inc.             plea
# 18                              A.P. Moller-Maersk, A/S             plea
# 19                               AA Communications Inc.             plea
# 20                                  AADCO Medical, Inc.             plea
# 21                    AAPEX Environmental Services Inc.             plea
# 22                                  AAR Contractor Inc.             plea
# 23    AB Volvo [on behalf of itself and subsidiaries...               DP
# 24                                             ABB Inc.             plea
# 25                                             ABB Ltd.               DP
# 26           ABB Middle East & Africa Participations AG             plea
# 27                             ABB Vetco Gray (UK) Ltd.             plea
# 28                                 ABB Vetco Gray, Inc.             plea
# 29                         ABC Money Transactions, Inc.             plea
# 30                 ABC Professional Tree Services, Inc.               NP
# 31                                   ABI's Clinic, Ltd.             plea
# 32                                       ABL Aero, Inc.             plea
# 33                                   ABN AMRO Bank N.V.               DP
# 34                                       ABT Associates               DP
# 35                          ACHIEVE TOTAL FITNESS, INC.             plea
# 36                              ACS Environmental, Inc.             plea
# 37                                 ADA Fabricators Inc.             plea
# 38      ADA-ES, Inc. & ADA Environmental Solutions, LLC               NP
# 39                                              AEB Co.             plea
# 40                                             AEM Inc.             plea
# 41                                  AEP Energy Services               DP
# 42                             AES Laurel Mountain, LLC             plea
# 43                                             AEY Inc.             plea
# 44                                          AGA Medical               DP
# 45                                           AGCO Corp.               DP
# 46                          AH Computer Consulting Inc.             plea
# 47                                                  AIG               NP
# 48                         AIG Financial Products Corp.               NP
# 49                    AIG-FP PAGIC Equity Holding Corp.               DP
# ...                                                 ...              ...
# 2988                                 Williams Power Co.               DP
# 2989                                 Wilshire Paint Co.             plea
# 2990                    Wilshire Restaurant Group, Inc.             plea
# 2991                                      Win Lee Corp.             plea
# 2992          Windshield Sales & Service of Dallas Inc.             plea
# 2993                   Windshield Sales & Service, Inc.             plea
# 2994                             Winn-Dixie Stores Inc.             plea
# 2995                               Wood Group P S N Inc             plea
# 2996                               Wood Group P S N Inc             plea
# 2997                  Woodbridge Foam Fabricating, Inc.             plea
# 2998                                Woodbury Homes Inc.             plea
# 2999                          Woodson & Associates Inc.             plea
# 3000         Woodville Warehousing and Distributing LLC             plea
# 3001                          Workplace Compliance Inc.             plea
# 3002                             World Electronics Inc.             plea
# 3003                World Wide Sports & Recreation Inc.             plea
# 3004         Wright Medical Technology Inc. (extension)               DP
# 3005                    Wright Medical Technology, Inc.               DP
# 3006                                   Wuu Jau Co. Inc.             plea
# 3007                        Wyeth Pharmaceuticals, Inc.             plea
# 3008                                    XTO Energy Inc.             plea
# 3009                           Xplor Energy SPV-1, Inc.             plea
# 3010                                          YCL Corp.             plea
# 3011                          Yamada Manufacturing Ltd.             plea
# 3012                           Yamashita Rubber Co. Ltd             plea
# 3013                      Yamato Global Logisitcs, Ltd.             plea
# 3014                           Yamulla Enterprises Inc.             plea
# 3015                              Yates Petroleum Corp.             plea
# 3016                                       Yazaki Corp.             plea
# 3017                          Yazdian Construction Inc.             plea
# 3018                           Yellott Enterprises Inc.             plea
# 3019                          Yonkers Contracting, Inc.               NP
# 3020                                   York Int'l Corp.               DP
# 3021                             Yourway Transport Inc.             plea
# 3022                                     Yu Hua Co. LLC             plea
# 3023                           Yusen Logistics Co. Ltd.             plea
# 3024                                       Z-Group, LLC             plea
# 3025                                         Z-Spa Inc.             plea
# 3026                         Z.A.S. International, Inc.             plea
# 3027                           ZAO Hewlett-Packard A.O.             plea
# 3028                                 ZHU & Partners LLC             plea
# 3029                Zavos Diagnostic Laboratories, Inc.             plea
# 3030                              Zein Automobiles Inc.             plea
# 3031                                  Zentner & Zentner             plea
# 3032                                     Zeon Chemicals             plea
# 3033                              Zimmer Holdings, Inc.               DP
# 3034                                 Zuger Kantonalbank               NP
# 3035                                Zwanger-Pesiri Inc.             plea
# 3036                                        e-gold Ltd.             plea
# 3037                                          eAir, LLC             plea
#
#       TOTAL_PAYMENT        DATE
# 0            272734  2003-06-17
# 1             24000  2005-01-25
# 2                50  2014-11-21
# 3             14640  2006-07-05
# 4             27500  2005-06-03
# 5            500000  2001-07-31
# 6              2000  2013-03-05
# 7             42000  2012-03-05
# 8                50  2014-11-24
# 9                50  2014-11-24
# 10           460000  2001-05-21
# 11            25000  2014-04-29
# 12             5000  2003-04-21
# 13           550000         NaN
# 14            15000  2012-09-11
# 15                0  2013-12-27
# 16           750000  2011-11-04
# 17            56730  2004-05-25
# 18           500000  2005-09-30
# 19          1508321  2009-04-24
# 20            52945  2016-06-30
# 21           166700  2012-03-26
# 22         24909032  2005-02-25
# 23          7000000  2008-03-20
# 24         17100000  2010-10-01
# 25         30420000  2010-09-29
# 26         53000000  2001-04-12
# 27          5250000  2004-07-15
# 28          5250000  2004-07-15
# 29                0  2012-08-31
# 30          2000000  2012-05-18
# 31           150000  2013-01-03
# 32           500000  2006-08-10
# 33        505000000  2010-05-10
# 34          2316266  2007-01-18
# 35                0  2015-03-30
# 36           500000  2006-04-03
# 37                0  2000-12-22
# 38                0  2013-09-11
# 39            25000  2000-07-20
# 40        200000000  2010-07-27
# 41         30000000  2005-01-26
# 42            30000  2016-02-12
# 43           500000  2011-01-07
# 44          2000000  2008-06-03
# 45          1600000  2009-09-29
# 46            75000  2013-07-26
# 47         25000000  2006-02-07
# 48         80000000  2004-11-30
# 49                0  2004-11-30
# ...             ...         ...
# 2988       50000000  2006-02-01
# 2989          48478  2006-07-17
# 2990          65000  2005-10-24
# 2991        1900000  2013-05-16
# 2992         250000  2003-12-23
# 2993         250000  2003-12-23
# 2994         200000  2006-05-31
# 2995        7000000  2017-03-08
# 2996        1800000  2017-03-08
# 2997        1789055  2014-10-03
# 2998          15000  2007-06-04
# 2999         175000  2005-12-07
# 3000           4000  2008-11-25
# 3001         209030  2010-10-01
# 3002          20000  2007-12-03
# 3003         650000  2003-08-08
# 3004              0  2011-09-01
# 3005              0  2010-10-01
# 3006         200000  2002-06-07
# 3007      233584000  2013-01-31
# 3008          20000  2008-05-21
# 3009        2500000  2015-03-23
# 3010           5000  2011-10-27
# 3011        2500000  2015-06-24
# 3012       11000000  2013-10-21
# 3013        2326774  2013-01-31
# 3014         250000  2001-10-23
# 3015          10000  2007-07-10
# 3016      470000000  2012-03-01
# 3017          20000  2011-01-26
# 3018          10900  2002-05-17
# 3019              0  2015-11-06
# 3020       10000000  2007-10-01
# 3021         250000  2008-12-10
# 3022          45000  2007-03-06
# 3023       15428207  2013-09-04
# 3024          86871  2014-04-03
# 3025         345547  2006-01-03
# 3026          35985  2014-08-29
# 3027       58772250  2014-10-07
# 3028          50000  2008-09-26
# 3029         250000  2015-03-23
# 3030         250000  2013-10-23
# 3031              0  2000-11-17
# 3032       10500000  2005-03-17
# 3033              0  2007-09-01
# 3034        3798000  2015-11-06
# 3035              0  2016-11-21
# 3036        2350000  2008-12-16
# 3037         200000  2014-06-20
#
# [3038 rows x 4 columns]

# %% [markdown]
# ## Confirm it has 3038 rows and 5 columns

# %%
df_new.shape
# Out:
# (3038, 4)

# %% [markdown]
# ## Using this subset, extract the year into a separate column called `year`
#
# Your machine will complain. **Let's talk about that error.**

# %%
df_new['YEAR'] = df_new.DATE.str[:4]
df_new.head()
# Out:
# c:\users\simon\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                                   COMPANY DISPOSITION_TYPE  TOTAL_PAYMENT  \
# 0  1st Union Transfer and Telegraph, Inc.             plea         272734
# 1                3D Poultry Loading, Inc.             plea          24000
# 2                         3rd & Bell, LLC             plea             50
# 3                          41 Market Inc.             plea          14640
# 4                            45,000, Inc.             plea          27500
#
#          DATE  YEAR
# 0  2003-06-17  2003
# 1  2005-01-25  2005
# 2  2014-11-21  2014
# 3  2006-07-05  2006
# 4  2005-06-03  2005

# %% [markdown]
# ## Make the 'year' column an integer.
#
# Or at least *try*, then turn it into a float. Why did one work but the other didn't?

# %%
df_new['YEAR'] = df_new.YEAR.astype(int, errors="ignore")
# Out:
# c:\users\simon\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new['YEAR'] = df_new.YEAR.astype(float)
# Out:
# c:\users\simon\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new.dtypes
# Out:
# COMPANY              object
# DISPOSITION_TYPE     object
# TOTAL_PAYMENT         int64
# DATE                 object
# YEAR                float64
# dtype: object

# %% [markdown]
# ## Make a histogram of cases over the years

# %%
minimum = df_new.min().YEAR.astype(int)
maximum = df_new.max().YEAR.astype(int)

# %%
df_new.YEAR.hist(bins=range(minimum, maximum))

# %% [markdown]
# ## What was the total amount paid across all cases each year?

# %%
df_new.groupby('YEAR')['TOTAL_PAYMENT'].sum()
# Out:
# YEAR
# 1,992             0
# 1,993             0
# 1,994             0
# 1,996             0
# 1,998             0
# 1,999             0
# 2,000     278206161
# 2,001     761777886
# 2,002     829424749
# 2,003     911162220
# 2,004    1637537063
# 2,005    4210235461
# 2,006    1201775794
# 2,007    3034830498
# 2,008    2729966187
# 2,009    4090513821
# 2,010    4745389066
# 2,011    2957950912
# 2,012    6696816915
# 2,013    7724920476
# 2,014    7062535053
# 2,015    9844845643
# 2,016    3808529923
# 2,017    6866002335
# Name: TOTAL_PAYMENT, dtype: int64

# %% [markdown]
# ## Graph it!

# %%
df_new.groupby('YEAR')['TOTAL_PAYMENT'].sum().plot(kind="bar")

# %% [markdown]
# # Cleaning up a column
#
# Take a look at **AGREEMENT_REQUIRED_NEW_POSITIONS** in your **ORIGINAL DATAFRAME**. How many times does it have a value in it?
#
# - Tip: There are a few ways to do this. Maybe you want to ask for an easy one!

# %%
df.AGREEMENT_REQUIRED_NEW_POSITIONS.notnull().value_counts(ascending=True)
# Out:
# True      261
# False    2777
# Name: AGREEMENT_REQUIRED_NEW_POSITIONS, dtype: int64

# %% [markdown]
# ### What are the top 5 responses for `AGREEMENT_REQUIRED_NEW_POSITIONS`?

# %%
df.AGREEMENT_REQUIRED_NEW_POSITIONS.value_counts().head(5)
# Out:
# No                                                                                       163
# Yes; Assignment one or more senior officers to compliance, with reporting obligations     46
# Yes; Compliance Officer                                                                    6
# Yes; Chief Compliance Officer                                                              6
# Yes; Compliance officer                                                                    3
# Name: AGREEMENT_REQUIRED_NEW_POSITIONS, dtype: int64

# %% [markdown]
# ## That looks messy.
#
# ### HOLD ON, time to learn something
#
# **There are a few ways to do the next question**, but a couple popular methods will have pandas yell at you. You might want to try this new thing called `loc`! **It is used to update a column in a row based on a condition.**
#
# ```
# df.loc[df.country == 'Angola', "continent"] = "Africa"
# ```
#
# This updates the `continent` column to be `Africa` for every row where `df.country == 'Angola'`. You CANNOT do the following, which is probably what you've wanted to do:
#
# ```
# df[df.country == 'Angola']['continent'] = 'Africa'
# ```
#
# And now you know.
#
# ## Start to this up by creating a new column called `required_new_position`.
#
# This column should be `True` if a new position was required, `False` if a new position was not required, and `NaN` if it's unknown.
#
# - Tip: You should use `.str.contains`
# - Tip: Do you know how to say "at the start of a line" using regex?
# - Tip: We've talked about how to avoid `cannot index with vector containing NA / NaN values` but if you get it feel free to write it on the board

# %%
df.loc[df.AGREEMENT_REQUIRED_NEW_POSITIONS.notnull(), 'REQUIRED_NEW_POSITION'] = df.AGREEMENT_REQUIRED_NEW_POSITIONS.str.extract(r"^\b(\w*)\b")
# Out:
# c:\users\simon\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Confirm that your new column has 163 `No` values and 98 `Yes` values

# %%
df.REQUIRED_NEW_POSITION.value_counts()
# Out:
# No     163
# Yes     98
# Name: REQUIRED_NEW_POSITION, dtype: int64

# %% [markdown]
# ## Extract the position name into a new column called `new_position`

# %%
df.loc[df.index, 'NEW_POSITION'] = df.AGREEMENT_REQUIRED_NEW_POSITIONS.str.extract(r"^Yes; (.*)")
# Out:
# c:\users\simon\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Make sure you extracted correctly
#
# The line below should show at least SIX rows. If it doesn't show any rows, something went wrong!
#
# - Tip: A `.value_counts()` might look okay, even though something is a little off.

# %%
df[df.NEW_POSITION == "Compliance Officer"]
# Out:
#       REC_ID                                            COMPANY  \
# 441      663                                         Boeing Co.
# 664      587                               Columbia Farms, Inc.
# 1063      51  Fisher Sand & Gravel / General Steel (subsid.)...
# 1657     609                                 Louis Berger Group
# 1661     610                              Love Irrigation, Inc.
# 3005     645                    Wright Medical Technology, Inc.
#
#      DISPOSITION_TYPE PRIMARY_CRIME_CODE SWISS_BANK_PROGRAM  \
# 441                NP    Fraud - General                 No
# 664                DP        Immigration                 No
# 1063               DP        Fraud - Tax                 No
# 1657               DP    Fraud - General                 No
# 1661               DP        Immigration                 No
# 3005               DP          Kickbacks                 No
#
#                                                    USAO        COUNTRY  \
# 441   California - Central District,Virginia - Easte...  United States
# 664                                      South Carolina  United States
# 1063                               USDOJ - Tax Division  United States
# 1657                                         New Jersey  United States
# 1661                    Mississippi - Southern District  United States
# 3005                                         New Jersey  United States
#
#      FINANCIAL_INSTITUTION CASE_NAME CASE_ID DOCKET_NO        DATE  \
# 441                     No       NaN     NaN       NaN  2006-06-01
# 664                     No       NaN     NaN       NaN  2009-11-03
# 1063                    No       NaN     NaN       NaN  2009-04-29
# 1657                   Yes       NaN     NaN       NaN  2010-11-05
# 1661                    No       NaN     NaN       NaN  2012-05-22
# 3005                    No       NaN     NaN       NaN  2010-10-01
#
#      JUDGMENT_DATE PLEA_DATE TICKER US_PUBLIC_CO  \
# 441            NaN       NaN    NaN          Yes
# 664            NaN       NaN    NaN           No
# 1063           NaN       NaN    NaN           No
# 1657           NaN       NaN    NaN           No
# 1661           NaN       NaN    NaN           No
# 3005           NaN       NaN    NaN          Yes
#
#       ADDITIONAL_REGULATORY_FINE_OR_PAYMENT  COMMUNITY_SERVICE_OR_OTHER  \
# 441                                       0                         nan
# 664                               1,500,000                         nan
# 1063                                668,141                         nan
# 1657                                      0                         nan
# 1661                                390,110                         nan
# 3005                                      0                         nan
#
#            FINE  FORFEITURE_DISGORGEMENT  PROBATION_LENGTH  RESTITUTION  \
# 441  50,000,000                      nan                24          nan
# 664           0                      nan                24    1,500,000
# 1063    500,000                      nan                30      668,141
# 1657 18,700,000                      nan                24          nan
# 1661    125,000                      nan                36      390,110
# 3005          0                      nan                12          nan
#
#       TOTAL_PAYMENT ACCEPTS_RESPONSIBILITY AGREEMENT_REQUIRED_NEW_POSITIONS  \
# 441        50000000                    Yes          Yes; Compliance Officer
# 664         1500000                    Yes          Yes; Compliance Officer
# 1063        1168141                    Yes          Yes; Compliance Officer
# 1657       18700000                    Yes          Yes; Compliance Officer
# 1661         515110                    Yes          Yes; Compliance Officer
# 3005              0                    Yes          Yes; Compliance Officer
#
#      AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS  \
# 441                                              No
# 664                                              No
# 1063                                             No
# 1657                                             No
# 1661                                            NaN
# 3005                                             No
#
#                                CITATION_AND_DESCRIPTION  \
# 441   Yes (RICO - possession of competitor documents...
# 664                                                 NaN
# 1063                                                NaN
# 1657                                                NaN
# 1661                                                NaN
# 3005                                                NaN
#
#      CIVIL_JUDGMENT_OR_SETTLEMENT  \
# 441                           NaN
# 664                           NaN
# 1063                          NaN
# 1657                          NaN
# 1661                          NaN
# 3005                          NaN
#
#                          COMPLIANCE_PROGRAM_DESCRIPTION  \
# 441   Training; discipline; prohibiting retaliation;...
# 664   Designation of compliance officer; ICE reporti...
# 1063  Designate Compliance Officer to oversee implem...
# 1657  Complaince, training, hotline, new compliance ...
# 1661  Use of e-verify, training, designate complianc...
# 3005  Compliance program; training; hotline; needs a...
#
#      COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT  \
# 441                                       Yes
# 664                                       Yes
# 1063                                      Yes
# 1657                                      Yes
# 1661                                      Yes
# 3005                                      Yes
#
#                       COMPLIANCE_REQUIRED_BY_REGULATORS  \
# 441   Yes; Interim Agreement with Air Force: maintai...
# 664                                                 NaN
# 1063                                                Yes
# 1657                                                 No
# 1661                                                 No
# 3005  Yes; Civil Settlement Agreement with civil div...
#
#                                              CRIME_DESC  \
# 441   Federal procurement fraud, conflict of interes...
# 664                       Immigration, false statements
# 1063                                          Tax fraud
# 1657                               Major Frauds Statute
# 1661    Immigration - harboring, employment, conspiracy
# 3005                              Anti-Kickback Statute
#
#      DESCRIPTION_OF_PAYMENTS  \
# 441                      NaN
# 664                      NaN
# 1063                     NaN
# 1657                     NaN
# 1661                     NaN
# 3005                     NaN
#
#      DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY  \
# 441   Yes; in exchange for good faith performance of...
# 664   Yes; acceptance of responsibility, compliance,...
# 1063  Yes; acceptance of responsibility, cooperation...
# 1657  Yes; acceptance of responsibility, cooperation...
# 1661  Yes; acceptance of responsibility, cooperation...
# 3005  Yes; remediation, acknowledging responsibility...
#
#                          DOJ_CAN_UNILATERALLY_TERMINATE  \
# 441   No; But "conduct by a Boeing employee classifi...
# 664                                                 Yes
# 1063                                                Yes
# 1657                                                Yes
# 1661                                                Yes
# 3005                                     Yes; If breach
#
#                 FINE_CALCULATION_INCLUDED  \
# 441                                    No
# 664                                    No
# 1063                                   No
# 1657                                   No
# 1661  Yes; Bottom end of Guidelines range
# 3005                                   No
#
#                                        FINE_DESCRIPTION  \
# 441   $50M penalty, $565M civil settlement; $1.9M to...
# 664                                               $1.5M
# 1063  $668,141 restitution for unpaid lax liability;...
# 1657                                                NaN
# 1661                                         $1 million
# 3005  $7.9 million to HHS-OIG, as part of joint sett...
#
#      INDEP_MONITOR_REQUIRED  \
# 441                     Yes
# 664                      No
# 1063                     No
# 1657                    Yes
# 1661                     No
# 3005                    Yes
#
#              MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE       OTHER_AGREEMENT  \
# 441        Yes; Periodic auditing of compliance program  Interim Admin. Agmt.
# 664   Yes; Use of e-Verify program, annual review of...                   NaN
# 1063  Yes; Compliance Officer must evaluate periodic...                   NaN
# 1657                                                 No                   NaN
# 1661                                                 No                   NaN
# 3005                                                 No                   NaN
#
#      OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES  \
# 441                                           No
# 664                                           No
# 1063                                          No
# 1657                Yes; New obligations of CFO)
# 1661                                         NaN
# 3005                                          No
#
#      OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED  \
# 441                                              Yes
# 664                                               No
# 1063                                              No
# 1657                                             Yes
# 1661                                             Yes
# 3005                                             Yes
#
#                                     PARALLEL_CIVIL_SUIT  \
# 441                                                 Yes
# 664                                                  No
# 1063                                                 No
# 1657                                                 No
# 1661                                                 No
# 3005  No; Implant lawsuits relate to design of produ...
#
#      PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR PRE_AGREEMENT_COMPLIANCE  \
# 441                                             Yes                      Yes
# 664                                             NaN                      Yes
# 1063                                            NaN                      Yes
# 1657                                             No                      Yes
# 1661                                       Yes; SEC                       No
# 3005                                   Yes; HHS-OIG                      Yes
#
#                    PRE_AGREEMENT_COMPLIANCE_DESCRIPTION PRIVACY_WAIVER  \
# 441   Yes; Changes to ethics and compliance program;...             No
# 664   Yes; Cites significant remedial actions taken ...             No
# 1063             Yes; Drafted a Code of Business Ethics             No
# 1657  Yes; "extensive reforms and remedial measures"...             No
# 1661                                                 No             No
# 3005  Yes; Described new policies, new Chief Complia...             No
#
#       REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE  REGULATORY_FINE  \
# 441                                        1,900,000      595,000,000
# 664                                              nan              nan
# 1063                                             nan              nan
# 1657                                             nan              nan
# 1661                                               0        1,500,000
# 3005                                               0        7,900,000
#
#                                              REG_AGENCY STATEMENT_OF_FACTS  \
# 441   National Aeronautics and Space Administration ...                Yes
# 664   Dept. of Homeland Security;Dept. of Homeland S...                Yes
# 1063  Dept. of the Treasury - Internal Revenue Servi...                Yes
# 1657  Dept. of Justice - Civil Division - Fraud Sect...                Yes
# 1661  Dept. of Homeland Security - Immigration & Cus...                Yes
# 3005  U.S. Postal Inspection Service (USPIS); Dept. ...                 No
#
#       TOTAL_REGULATORY UNRELATED_TERMS  AGMT_YEAR SOURCE  \
# 441        596,900,000              No      2,006    NaN
# 664                  0              No      2,009    NaN
# 1063                 0              No      2,009    NaN
# 1657                 0              No      2,010    NaN
# 1661         1,500,000              No      2,012    NaN
# 3005         7,900,000              No      2,010    NaN
#
#                                                   NOTES REQUIRED_NEW_POSITION  \
# 441   Information regarding the Interim Agreement: h...                   Yes
# 664                                                 NaN                   Yes
# 1063                                                NaN                   Yes
# 1657                                                NaN                   Yes
# 1661                                                NaN                   Yes
# 3005                                                NaN                   Yes
#
#             NEW_POSITION
# 441   Compliance Officer
# 664   Compliance Officer
# 1063  Compliance Officer
# 1657  Compliance Officer
# 1661  Compliance Officer
# 3005  Compliance Officer

# %% [markdown]
# ## Find all cases that required a compliance officer
#
# That one above only gives us six. We want more! **Find at least 23 cases that required the creation of a compliance officer.**
#
# - Tip: Regular expressions might be your friend here
# - Tip: If you get an error about **new_position** not being found, change your code from when you created the column from `df.new_position = ...` to `df['new_position'] = ...`

# %%
df_temp = df[df.NEW_POSITION.notnull()]

# %%
df_comp_off = df_temp[df_temp.NEW_POSITION.str.contains(r"\bcompliance\b.*\bofficer\b", case=False)]
df_comp_off['NEW_POSITION']
# Out:
# 226                                                                                                                                                                             Compliance officer
# 276                                                                                                                                                                       Chief Compliance Officer
# 278                  Compliance officer, two independent and outside directors including one to serve on audit committee consulting with DOJ on personnell decisions related to compliance program
# 305                                                                                                                                                            Designate CEO as Compliance officer
# 362                                                                                                                                                                       Chief Compliance Officer
# 415           Expanded compliance department, compliance officer, established Research Committee, Compliance Officer and Vide President and Corporate Compliance Officer with set responsibilities
# 441                                                                                                                                                                             Compliance Officer
# 664                                                                                                                                                                             Compliance Officer
# 682     Two new independent directors to Board, establish Compliance Committee, Disclosure Committee, hire five new internal auditors, new Chief Compliance Officer, reorganize Finance Department
# 732                                                                                                                                                           Independent Chief Compliance Officer
# 836                                                                                             Appoint Chief Compliance Officer as member of Board, create Office of the Chief Compliance Officer
# 1003                                                                                                                             Compliance Officer, reporting to President, CEO, Board Committees
# 1023                                                                                                                                                                            compliance officer
# 1063                                                                                                                                                                            Compliance Officer
# 1094                                                                                                       Compliance Officer, create Audit Committee, Nomination Committee, Compensation Commitee
# 1161                                                                                                                                                                            Compliance officer
# 1362                                                                                                                                                                  Full time Compliance Officer
# 1460                                                                                                                                                                            Compliance officer
# 1490                                                                                                                                                                      Chief Compliance Officer
# 1512                                                                                                                                                                      Chief Compliance Officer
# 1627                                                                                                   Create new Ethics and Compliance Officer, full-time auditor posittion, new liaison position
# 1657                                                                                                                                                                            Compliance Officer
# 1661                                                                                                                                                                            Compliance Officer
# 1760                                                                                                                                                                      Chief Compliance Officer
# 2123                                                                Retaining full time Chief Compliance Officer; assignment one or more senior officers to compliance, with reporting obligations
# 2608                                                                                                                                                  New Compliance Office and Compliance Officer
# 2853                                                                                                                                                                      Chief Compliance Officer
# 3005                                                                                                                                                                            Compliance Officer
# 3033                                                                                                                                  Create Compliance Office, headed by Chief Compliance Officer
# Name: NEW_POSITION, dtype: object

# %% [markdown]
# ## View the cases that have a compliance officer again.
#
# This time you shouldn't have a `...` in the middle of your dataframe.

# %%
pd.options.display.max_colwidth = 200

# %%
df_comp_off.NEW_POSITION
# Out:
# 226                                                                                                                                                                             Compliance officer
# 276                                                                                                                                                                       Chief Compliance Officer
# 278                  Compliance officer, two independent and outside directors including one to serve on audit committee consulting with DOJ on personnell decisions related to compliance program
# 305                                                                                                                                                            Designate CEO as Compliance officer
# 362                                                                                                                                                                       Chief Compliance Officer
# 415           Expanded compliance department, compliance officer, established Research Committee, Compliance Officer and Vide President and Corporate Compliance Officer with set responsibilities
# 441                                                                                                                                                                             Compliance Officer
# 664                                                                                                                                                                             Compliance Officer
# 682     Two new independent directors to Board, establish Compliance Committee, Disclosure Committee, hire five new internal auditors, new Chief Compliance Officer, reorganize Finance Department
# 732                                                                                                                                                           Independent Chief Compliance Officer
# 836                                                                                             Appoint Chief Compliance Officer as member of Board, create Office of the Chief Compliance Officer
# 1003                                                                                                                             Compliance Officer, reporting to President, CEO, Board Committees
# 1023                                                                                                                                                                            compliance officer
# 1063                                                                                                                                                                            Compliance Officer
# 1094                                                                                                       Compliance Officer, create Audit Committee, Nomination Committee, Compensation Commitee
# 1161                                                                                                                                                                            Compliance officer
# 1362                                                                                                                                                                  Full time Compliance Officer
# 1460                                                                                                                                                                            Compliance officer
# 1490                                                                                                                                                                      Chief Compliance Officer
# 1512                                                                                                                                                                      Chief Compliance Officer
# 1627                                                                                                   Create new Ethics and Compliance Officer, full-time auditor posittion, new liaison position
# 1657                                                                                                                                                                            Compliance Officer
# 1661                                                                                                                                                                            Compliance Officer
# 1760                                                                                                                                                                      Chief Compliance Officer
# 2123                                                                Retaining full time Chief Compliance Officer; assignment one or more senior officers to compliance, with reporting obligations
# 2608                                                                                                                                                  New Compliance Office and Compliance Officer
# 2853                                                                                                                                                                      Chief Compliance Officer
# 3005                                                                                                                                                                            Compliance Officer
# 3033                                                                                                                                  Create Compliance Office, headed by Chief Compliance Officer
# Name: NEW_POSITION, dtype: object

# %% [markdown]
# ## What were the most popular crimes that required a compliance officer's appointment?

# %%
df_comp_off.PRIMARY_CRIME_CODE.value_counts()
# Out:
# Kickbacks              5
# Fraud - General        5
# Immigration            5
# Fraud - Tax            3
# FCPA                   3
# Fraud - Securities     2
# Fraud - Health Care    2
# Environmental          1
# Other                  1
# Food                   1
# Fraud - Accounting     1
# Name: PRIMARY_CRIME_CODE, dtype: int64

# %% [markdown]
# # Make a comparison between two groups in the full dataset
#
# For example, "cases before 2003 were likely to be about this, but after 2003 they became about something else."

# %%
df.groupby('SWISS_BANK_PROGRAM')['TOTAL_PAYMENT'].mean()
# Out:
# SWISS_BANK_PROGRAM
# No    59,896,900
# Yes   16,961,974
# Name: TOTAL_PAYMENT, dtype: float64

# %%
df.groupby('SWISS_BANK_PROGRAM')['TOTAL_PAYMENT'].mean().plot(kind="bar")
