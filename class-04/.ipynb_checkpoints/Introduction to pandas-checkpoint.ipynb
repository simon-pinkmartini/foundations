# %% [markdown]
# # Introduction to pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("countries.csv")

# %%
# Let's look at the first few rows
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
# How about the last few rows?
df.tail()
# Out:
#                 Country Continent  GDP_per_capita  life_expectancy  Population
# 183             Vietnam      Asia            1577           73.777    78758010
# 184  West Bank and Gaza      Asia            7586           70.929     3198560
# 185         Yemen, Rep.      Asia            2217           60.404    17723186
# 186              Zambia    Africa            1035           41.802    10201562
# 187            Zimbabwe    Africa             745           43.976    12509477

# %%
df.columns
# Out:
# Index(['Country', 'Continent', 'GDP_per_capita', 'life_expectancy',
#        'Population'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country             object
# Continent           object
# GDP_per_capita       int64
# life_expectancy    float64
# Population           int64
# dtype: object

# %%
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
# Put things in order
df.sort_values(by="Population", ascending=False)
# Out:
#                               Country   Continent  GDP_per_capita  \
# 34                              China        Asia            3407
# 75                              India        Asia            1648
# 178                     United States  N. America           39758
# 76                          Indonesia        Asia            2714
# 22                             Brazil  S. America            8056
# 137                            Russia        Asia            8570
# 127                          Pakistan        Asia            2086
# 12                         Bangladesh        Asia            1075
# 83                              Japan        Asia           28559
# 124                           Nigeria      Africa            1619
# 110                            Mexico  N. America           10894
# 61                            Germany      Europe           29726
# 183                           Vietnam        Asia            1577
# ...

# %%
df.sort_values?

# %%
# True and False are BOOLEAN values
# true/values, but they're special with a capital T or F

# %%
# One column is called a Series
df["Population"]
# Out:
# 0       22856302
# 1        3071856
# 2       30533827
# 3       13926373
# 4          77656
# 5       36930709
# 6        3076098
# 7       19164351
# 8        8004712
# 9        8110723
# 10        297651
# 11        638193
# 12     129592275
# 13        267511
# 14      10057810
# 15      10175684
# 16        250512
# 17       6517810
# 18        571262
# 19       8307248
# 20       3693698
# 21       1757925
# 22     174425387
# 23        327036
# 24       8006158
# 25      12294012
# 26       6374347
# 27      12446949
# 28      15678269
# 29      30667365
#          ...
# 158       466846
# 159      1063832
# 160      8860153
# 161      7167908
# 162     15988534
# 163     22183000
# 164      6172807
# 165     34038161
# 166     63155029
# 167       830089
# 168      4793504
# 169        97935
# 170      1292058
# 171      9456117
# 172     63627862
# 173      4501419
# 174     24213120
# 175     48891792
# 176      3033491
# 177     58874117
# 178    282496310
# ...

# %%
df["Population"].sum()
# Out:
# 6115042358

# %%
df["Population"].median()
# Out:
# 6888970.5

# %%
df["Population"].mean()
# Out:
# 32526821.05319149

# %%
df["Population"].std()
# Out:
# 123795162.37011255

# %%
df["Population"].max()
# Out:
# 1269116737

# %%
# This is how you talk about number columns
df["Population"].describe().astype(int)
# Out:
# count           188
# mean       32526821
# std       123795162
# min           56196
# 25%         2003169
# 50%         6888970
# 75%        22185170
# max      1269116737
# Name: Population, dtype: int64

# %%
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
df['Continent']
# Out:
# 0            Asia
# 1          Europe
# 2          Africa
# 3          Africa
# 4      N. America
# 5      S. America
# 6          Europe
# 7         Oceania
# 8          Europe
# 9          Europe
# 10     N. America
# 11           Asia
# 12           Asia
# 13     N. America
# 14         Europe
# 15         Europe
# 16     N. America
# 17         Africa
# 18           Asia
# 19     S. America
# 20         Europe
# 21         Africa
# 22     S. America
# 23           Asia
# 24         Europe
# 25         Africa
# 26         Africa
# 27           Asia
# 28         Africa
# 29     N. America
#           ...
# 158    S. America
# 159        Africa
# 160        Europe
# 161        Europe
# 162          Asia
# 163          Asia
# 164          Asia
# 165        Africa
# 166          Asia
# 167          Asia
# 168        Africa
# 169       Oceania
# 170    N. America
# 171        Africa
# 172          Asia
# 173          Asia
# 174        Africa
# 175        Europe
# 176          Asia
# ...

# %%
# If you want to know stuff about a non-numeric column
df['Continent'].value_counts()
# Out:
# Africa        54
# Asia          48
# Europe        42
# N. America    22
# S. America    12
# Oceania       10
# Name: Continent, dtype: int64

# %%
# describe isn't as good for string columns
df['Continent'].describe()
# Out:
# count        188
# unique         6
# top       Africa
# freq          54
# Name: Continent, dtype: object

# %%
df['Continent'].value_counts().plot()

# %%
# matplotlib is a Python graphing library
# and we use this MAGIC jupyter line in order
# to tell it to put graphs into the notebook
# %matplotlib inline

# %%
df['Continent'].value_counts().plot?
# Out:
# Object `plot` not found.

# %%
df['Continent'].value_counts().plot(kind='bar')

# %%
df['Continent'].value_counts().plot(kind='barh')

# %%
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
df.plot(kind='scatter', x='GDP_per_capita', y='life_expectancy')

# %%
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
df['life_expectancy'].plot(kind='bar')

# %%
df.groupby("Continent")

# %%
df.groupby("Continent")["GDP_per_capita"]

# %%
# We needed:
# What column to group by
# What column we want information about
# And what kind of information we want about that column
df.groupby("Continent")["GDP_per_capita"].mean()
# Out:
# Continent
# Africa         2621.648148
# Asia          11106.437500
# Europe        18647.880952
# N. America    11665.681818
# Oceania        8038.400000
# S. America     6738.583333
# Name: GDP_per_capita, dtype: float64

# %%
# how many rows and columns
df.shape
# Out:
# (188, 5)

# %%
patient = { 'temperature': 108, 'condition': 'severe' }

# %%
patient['temperature'] > 104
# Out:
# True

# %%
# How do you say:
# Hey dataframe, is your continent Asia?
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
df['Continent'] == 'Asia'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12      True
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18      True
# 19     False
# 20     False
# 21     False
# 22     False
# 23      True
# 24     False
# 25     False
# 26     False
# 27      True
# 28     False
# 29     False
#        ...
# 158    False
# 159    False
# 160    False
# 161    False
# 162     True
# 163     True
# 164     True
# 165    False
# 166     True
# 167     True
# 168    False
# 169    False
# 170    False
# 171    False
# 172     True
# 173     True
# 174    False
# 175    False
# 176     True
# 177    False
# 178    False
# 179    False
# 180     True
# 181    False
# 182    False
# 183     True
# 184     True
# 185     True
# 186    False
# 187    False
# Name: Continent, dtype: bool

# %%
# df[   ] on the outside
# and your comparison on the inside
df[df['Continent'] == 'Asia']
# Out:
#                   Country Continent  GDP_per_capita  life_expectancy  \
# 0             Afghanistan      Asia             663           54.863
# 11                Bahrain      Asia           22015           74.497
# 12             Bangladesh      Asia            1075           65.309
# 18                 Bhutan      Asia            2922           60.307
# 23                 Brunei      Asia           48020           75.927
# 27               Cambodia      Asia             982           62.030
# 34                  China      Asia            3407           72.124
# 72       Hong Kong, China      Asia           29972           80.361
# 75                  India      Asia            1648           62.129
# 76              Indonesia      Asia            2714           67.289
# 77                   Iran      Asia            8600           69.611
# 78                   Iraq      Asia            3951           70.845
# 80                 Israel      Asia           22834           78.750
# ...

# %%
df['GDP_per_capita'].mean()
# Out:
# 9977.5585106382987

# %%
# Is your GDP per capita above the mean???????????
df['GDP_per_capita'] > df['GDP_per_capita'].mean()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5       True
# 6      False
# 7       True
# 8       True
# 9      False
# 10      True
# 11      True
# 12     False
# 13      True
# 14     False
# 15      True
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23      True
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29      True
#        ...
# 158    False
# 159    False
# 160     True
# 161     True
# 162    False
# 163     True
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170     True
# 171    False
# 172    False
# 173    False
# 174    False
# 175    False
# 176     True
# 177     True
# 178     True
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# Name: GDP_per_capita, dtype: bool

# %%
# Is your GDP per capita above the mean???????????
# I want those rows!!!
df[df['GDP_per_capita'] > df['GDP_per_capita'].mean()]
# Out:
#                   Country   Continent  GDP_per_capita  life_expectancy  \
# 4     Antigua and Barbuda  N. America           12738        73.544000
# 5               Argentina  S. America           10571        73.822000
# 7               Australia     Oceania           29241        79.930000
# 8                 Austria      Europe           32008        78.330000
# 10                Bahamas  N. America           22728        72.370000
# 11                Bahrain        Asia           22015        74.497000
# 13               Barbados  N. America           14982        73.118000
# 15                Belgium      Europe           29940        77.910000
# 21               Botswana      Africa           10107        50.567000
# 23                 Brunei        Asia           48020        75.927000
# 29                 Canada  N. America           32448        79.410000
# 33                  Chile  S. America           10435        77.010000
# ...

# %%
df[(df['Continent'] == 'Asia') & (df['GDP_per_capita'] > df['GDP_per_capita'].mean())]
# Out:
#                   Country Continent  GDP_per_capita  life_expectancy  \
# 11                Bahrain      Asia           22015           74.497
# 23                 Brunei      Asia           48020           75.927
# 72       Hong Kong, China      Asia           29972           80.361
# 80                 Israel      Asia           22834           78.750
# 83                  Japan      Asia           28559           81.350
# 89            Korea, Rep.      Asia           16995           76.114
# 90                 Kuwait      Asia           36397           73.133
# 100          Macao, China      Asia           22512           77.627
# 104              Malaysia      Asia           10161           72.810
# 126                  Oman      Asia           19204           72.139
# 135                 Qatar      Asia           60394           76.680
# 143          Saudi Arabia      Asia           20001           72.401
# 148             Singapore      Asia           36834           78.340
# ...

# %%
df['Population'] / 1000000
# Out:
# 0       22.856302
# 1        3.071856
# 2       30.533827
# 3       13.926373
# 4        0.077656
# 5       36.930709
# 6        3.076098
# 7       19.164351
# 8        8.004712
# 9        8.110723
# 10       0.297651
# 11       0.638193
# 12     129.592275
# 13       0.267511
# 14      10.057810
# 15      10.175684
# 16       0.250512
# 17       6.517810
# 18       0.571262
# 19       8.307248
# 20       3.693698
# 21       1.757925
# 22     174.425387
# 23       0.327036
# 24       8.006158
# 25      12.294012
# 26       6.374347
# 27      12.446949
# 28      15.678269
# 29      30.667365
#           ...
# 158      0.466846
# 159      1.063832
# 160      8.860153
# 161      7.167908
# 162     15.988534
# 163     22.183000
# 164      6.172807
# 165     34.038161
# 166     63.155029
# 167      0.830089
# 168      4.793504
# 169      0.097935
# 170      1.292058
# 171      9.456117
# 172     63.627862
# 173      4.501419
# 174     24.213120
# 175     48.891792
# 176      3.033491
# ...

# %%
df.head()
# Out:
# 0       22.856302
# 1        3.071856
# 2       30.533827
# 3       13.926373
# 4        0.077656
# 5       36.930709
# 6        3.076098
# 7       19.164351
# 8        8.004712
# 9        8.110723
# 10       0.297651
# 11       0.638193
# 12     129.592275
# 13       0.267511
# 14      10.057810
# 15      10.175684
# 16       0.250512
# 17       6.517810
# 18       0.571262
# 19       8.307248
# 20       3.693698
# 21       1.757925
# 22     174.425387
# 23       0.327036
# 24       8.006158
# 25      12.294012
# 26       6.374347
# 27      12.446949
# 28      15.678269
# 29      30.667365
#           ...
# 158      0.466846
# 159      1.063832
# 160      8.860153
# 161      7.167908
# 162     15.988534
# 163     22.183000
# 164      6.172807
# 165     34.038161
# 166     63.155029
# 167      0.830089
# 168      4.793504
# 169      0.097935
# 170      1.292058
# 171      9.456117
# 172     63.627862
# 173      4.501419
# 174     24.213120
# 175     48.891792
# 176      3.033491
# ...

# %%
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
# Save it into a new column, then use .head to check it
df['millions'] = df['Population'] / 1000000
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population   millions
# 0    22856302  22.856302
# 1     3071856   3.071856
# 2    30533827  30.533827
# 3    13926373  13.926373
# 4       77656   0.077656

# %%
df['GDP'] = df['GDP_per_capita'] * df['Population'] / 1000000000
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population   millions         GDP
# 0    22856302  22.856302   15.153728
# 1     3071856   3.071856   12.886436
# 2    30533827  30.533827  155.661450
# 3    13926373  13.926373   34.063908
# 4       77656   0.077656    0.989182

# %%
df.GDP_per_capita * df.Population
# Out:
# 0         15153728226
# 1         12886435920
# 2        155661450046
# 3         34063908358
# 4           989182128
# 5        390394524839
# 6          6502871172
# 7        560384787591
# 8        256214821696
# 9         20544461359
# 10         6765011928
# 11        14049818895
# 12       139311695625
# 13         4007849802
# 14        59703160160
# 15       304659978960
# 16         1639601040
# 17         8518777670
# 18         1669227564
# 19        28194799712
# 20        21175970634
# 21        17767347975
# 22      1405170917672
# 23        15704268720
# 24        55298533306
# 25        12306306012
# 26         2823835721
# 27        12222903918
# 28        28267919007
# 29       995094659520
#             ...
# 158        2650284742
# 159        4277668472
# 160      253754781920
# 161      246475684488
# 162       62914881290
# 163      521855075000
# 164        6178979807
# 165       28115520986
# 166      352278751762
# 167        2276934127
# ...

# %%
df[(df.Continent == 'Asia') & (df.GDP_per_capita > df.GDP_per_capita.mean())]
# Out:
#                   Country Continent  GDP_per_capita  life_expectancy  \
# 11                Bahrain      Asia           22015           74.497
# 23                 Brunei      Asia           48020           75.927
# 72       Hong Kong, China      Asia           29972           80.361
# 80                 Israel      Asia           22834           78.750
# 83                  Japan      Asia           28559           81.350
# 89            Korea, Rep.      Asia           16995           76.114
# 90                 Kuwait      Asia           36397           73.133
# 100          Macao, China      Asia           22512           77.627
# 104              Malaysia      Asia           10161           72.810
# 126                  Oman      Asia           19204           72.139
# 135                 Qatar      Asia           60394           76.680
# 143          Saudi Arabia      Asia           20001           72.401
# 148             Singapore      Asia           36834           78.340
# ...

# %%
df.groupby("Continent")['GDP_per_capita'].mean()
# Out:
# Continent
# Africa         2621.648148
# Asia          11106.437500
# Europe        18647.880952
# N. America    11665.681818
# Oceania        8038.400000
# S. America     6738.583333
# Name: GDP_per_capita, dtype: float64

# %%
df.groupby?

# %%
countries_df
something_else_df
# Out:
# '0.19.2'

# %%
"hello".upper

# %%
df[['Continent', 'Population']]
# Out:
#       Continent  Population
# 0          Asia    22856302
# 1        Europe     3071856
# 2        Africa    30533827
# 3        Africa    13926373
# 4    N. America       77656
# 5    S. America    36930709
# 6        Europe     3076098
# 7       Oceania    19164351
# 8        Europe     8004712
# 9        Europe     8110723
# 10   N. America      297651
# 11         Asia      638193
# 12         Asia   129592275
# 13   N. America      267511
# 14       Europe    10057810
# 15       Europe    10175684
# 16   N. America      250512
# 17       Africa     6517810
# 18         Asia      571262
# 19   S. America     8307248
# 20       Europe     3693698
# 21       Africa     1757925
# 22   S. America   174425387
# 23         Asia      327036
# 24       Europe     8006158
# 25       Africa    12294012
# 26       Africa     6374347
# 27         Asia    12446949
# 28       Africa    15678269
# 29   N. America    30667365
# ..          ...         ...
# 158  S. America      466846
# ...

# %%
df
# Out:
#                     Country   Continent  GDP_per_capita  life_expectancy  \
# 0               Afghanistan        Asia             663           54.863
# 1                   Albania      Europe            4195           74.200
# 2                   Algeria      Africa            5098           68.963
# 3                    Angola      Africa            2446           45.234
# 4       Antigua and Barbuda  N. America           12738           73.544
# 5                 Argentina  S. America           10571           73.822
# 6                   Armenia      Europe            2114           71.494
# 7                 Australia     Oceania           29241           79.930
# 8                   Austria      Europe           32008           78.330
# 9                Azerbaijan      Europe            2533           66.851
# 10                  Bahamas  N. America           22728           72.370
# 11                  Bahrain        Asia           22015           74.497
# ...
