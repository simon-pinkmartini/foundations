# %% [markdown]
# # A dataset about cans of beer.
#
# Data from http://craftcans.com/

# %% [markdown]
# ## Do your importing and your setup

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Read in the file `craftcans.csv`, and look at the first first rows

# %%
df = pd.read_csv("craftcans.csv")

# %%
df.head(2)
# Out:
#             Beer            Brewery         Location               Style  \
# 0   Get Together  NorthGate Brewing  Minneapolis, MN        American IPA
# 1  Maggie's Leap  NorthGate Brewing  Minneapolis, MN  Milk / Sweet Stout
#
#      Size    ABV  IBUs
# 0  16 oz.  4.50%  50.0
# 1  16 oz.  4.90%  26.0

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?

# %%
df.shape #we have 2416 rows
# Out:
# (2416, 7)

# %%
df.dtypes #we have 7 columns, all text except "IBUs"
# Out:
# Beer         object
# Brewery      object
# Location     object
# Style        object
# Size         object
# ABV          object
# IBUs        float64
# dtype: object

# %% [markdown]
# # Checking out breweries
#
# Where does beer come from????

# %% [markdown]
# ## What are the top 10 producers of cans of beer?

# %%
df["Brewery"].value_counts().head(10) #the top brewery is "Brewery Vivant"
# Out:
# Brewery Vivant                62
# Oskar Blues Brewery           46
# Sun King Brewing Company      38
# Cigar City Brewing Company    25
# Sixpoint Craft Ales           24
# Hopworks Urban Brewery        23
# Stevens Point Brewery         22
# 21st Amendment Brewery        20
# Great Crescent Brewery        20
# Bonfire Brewing Company       19
# Name: Brewery, dtype: int64

# %% [markdown]
# ## What is the most common size of beer?
#
# The answer won't be pretty - we'll learn to clean it up in a week or two.

# %%
df["Size"].value_counts() 
#the entry format wasn't strictly followed. but from the values, safe to say that 12 oz. is most common size
# Out:
# 12 oz.               1507
# 16 oz.                814
# 24 oz.                 21
# 16 oz. Alumi-Tek®      15
# 19.2 oz.               14
# 12 oz                  14
# 16 oz                  12
# 32 oz.                  5
# 12 ounce                1
# 12 oz. Slimline         1
# 16.9 oz.                1
# 24 oz. "Silo Can"       1
# 19.2                    1
# 12 & 16 oz.             1
# 12 OZ.                  1
# 8.4 oz.                 1
# Name: Size, dtype: int64

# %% [markdown]
# ## What is the most common ABV? (alcohol by volume)

# %%
df["ABV"].value_counts().head(10)
#most common ABV-Value is 5.00%
# Out:
# 5.00%    215
# 5.50%    158
# 6.00%    125
# 6.50%    123
# 5.20%    107
# 7.00%     92
# 4.50%     89
# 4.80%     72
# 5.80%     66
# 5.60%     66
# Name: ABV, dtype: int64

# %% [markdown]
# ## Oh, weird, ABV isn't a number. Convert it to a number for me, please.
#
# It's going to take three steps:
#
# 1. List just the ABV of every row
# 2. Remove the % symbol
# 3. Convert it to a `float`
# 4. Save it into a new column. Or the same column, if you're feeling wild.
#
# Although it *also* turns out that there's some bad data in there. We'll need to clean that up, too.

# %%
df["ABV2"] = df["ABV"].str.replace("?", "").str.replace("%", "")

# %%
df["ABV2"].astype(float) #I keep getting errors here
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-6c1153f0bdaf> in <module>()
# ----> 1 df["ABV2"].astype(float)
#
# c:\users\simon\appdata\local\programs\python\python36-32\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# c:\users\simon\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3408         # else, only a single dtype is given
#    3409         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 3410                                      **kwargs)
#    3411         return self._constructor(new_data).__finalize__(self)
#    3412
#
# c:\users\simon\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in astype(self, dtype, **kwargs)
#    3222
#    3223     def astype(self, dtype, **kwargs):
# -> 3224         return self.apply('astype', dtype=dtype, **kwargs)
#    3225
#    3226     def convert(self, **kwargs):
#
# c:\users\simon\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3089
#    3090             kwargs['mgr'] = self
# -> 3091             applied = getattr(b, f)(**kwargs)
#    3092             result_blocks = _extend_blocks(applied, result_blocks)
#    3093
#
# c:\users\simon\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     469     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     470         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 471                             **kwargs)
#     472
#     473     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# c:\users\simon\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     519
#     520                 # _astype_nansafe works fine with 1-d only
# --> 521                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     522                 values = values.reshape(self.shape)
#     523
#
# c:\users\simon\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy)
#     634
#     635     if copy:
# --> 636         return arr.astype(dtype)
#     637     return arr.view(dtype)
#     638
#
# ValueError: could not convert string to float:

# %% [markdown]
# # Looking at location
#
# Brooklyn used to produce 80% of the country's beer! Let's see if it's still true.

# %% [markdown]
# ## What are the top 10 cities in the US for canned craft beer?

# %%
df["Location"].value_counts().head(10)
#No! Grand Rapids is Number 1. Brooklyn only No. 8
# Out:
# Grand Rapids, MI    66
# Chicago, IL         55
# Portland, OR        52
# Indianapolis, IN    43
# San Diego, CA       42
# Boulder, CO         41
# Denver, CO          40
# Brooklyn, NY        38
# Seattle, WA         35
# Longmont, CO        33
# Name: Location, dtype: int64

# %% [markdown]
# ## List all of the beer from Brooklyn, NY

# %%
df[df["Location"] == "Brooklyn, NY"]
# Out:
#                                  Beer              Brewery      Location  \
# 115                            4Beans  Sixpoint Craft Ales  Brooklyn, NY
# 210                            Jammer  Sixpoint Craft Ales  Brooklyn, NY
# 246                           Abigale  Sixpoint Craft Ales  Brooklyn, NY
#
# 1270                    American IPA             16 oz.   6.40%   62.0   6.40
# 1305                  Czech Pilsener             12 oz.   5.50%   23.0   5.50
# 1365         American Pale Ale (APA)             12 oz.   5.50%    NaN   5.50
# 1366                    American IPA             12 oz.   2.70%    NaN   2.70
# 1373    English India Pale Ale (IPA)             16 oz.   6.80%   47.0   6.80
# 1624                   Baltic Porter             12 oz.   9.90%   85.0   9.90
# 1836              American Brown Ale             16 oz.   5.90%   47.0   5.90
# 1857           English Pale Mild Ale             12 oz.   4.50%    NaN   4.50
# 1962         American Pale Ale (APA)             12 oz.   5.50%    NaN   5.50
# 1970         American Pale Wheat Ale             16 oz.   5.20%   11.0   5.20
# 1971          Saison / Farmhouse Ale             16 oz.   4.90%   35.0   4.90
# 1972  American Double / Imperial IPA             12 oz.   9.10%  103.0   9.10
# 2027    English India Pale Ale (IPA)             12 oz.   6.80%   47.0   6.80
# 2062                  American Stout             16 oz.   6.30%   69.0   6.30
# 2074                     Pumpkin Ale             16 oz.   6.00%   48.0   6.00
# 2140                 German Pilsener             16 oz.   5.40%   42.0   5.40
# 2141                       Cream Ale             16 oz.   5.20%   34.0   5.20
# 2142                        Rye Beer             16 oz.   6.30%   57.0   6.30
# 2143                    American IPA             16 oz.   6.40%   62.0   6.40
# 2219           English Pale Mild Ale             12 oz.   4.50%    NaN   4.50
# 2350      American Amber / Red Lager             16 oz.   5.20%    NaN   5.20
# 2351      American Amber / Red Lager             12 oz.   5.20%    NaN   5.20

# %% [markdown]
# ## What brewery in Brooklyn puts out the most cans of beer?

# %%
df[df["Location"] == "Brooklyn, NY"]["Brewery"].value_counts()
#It's Sixpoint Craft Ales
# Out:
# Sixpoint Craft Ales    24
# Brooklyn Brewery        6
# Evil Twin Brewing       5
# KelSo Beer Company      3
# Name: Brewery, dtype: int64

# %% [markdown]
# ## What are the five most popular styles of beer produced by Sixpoint?

# %%
df[df["Brewery"] == "Sixpoint Craft Ales"]["Style"].value_counts().head(5)
# Out:
# American IPA                      4
# Baltic Porter                     2
# Rye Beer                          2
# German Pilsener                   2
# American Double / Imperial IPA    2
# Name: Style, dtype: int64

# %% [markdown]
# ## List all of the breweries in New York state. Then count them.

# %%
df[df["Location"].str[-2:] == "NY"]["Brewery"].value_counts()
# Out:
# Sixpoint Craft Ales              24
# Matt Brewing Company             13
# Brooklyn Brewery                  6
# Evil Twin Brewing                 5
# Butternuts Beer and Ale           4
# Blue Point Brewing Company        4
# KelSo Beer Company                3
# The Bronx Brewery                 3
# Montauk Brewing Company           2
# Bomb Beer Company                 2
# Upstate Brewing Company           2
# Chatham Brewing                   2
# Dundee Brewing Company            1
# Newburgh Brewing Company          1
# The Manhattan Brewing Company     1
# Southampton Publick House         1
# Name: Brewery, dtype: int64

# %%
len(df[df["Location"].str[-2:] == "NY"]["Brewery"].value_counts())
#There are 16 Breweries in NY State
# Out:
# 16

# %% [markdown]
# # Measuring International Bitterness Units
#
# IBU stands for [International Bitterness Unit](http://www.thebrewenthusiast.com/ibus/), and while a lot of places like to brag about having the most bitter beer (it's an American thing!), IBUs don't necessary *mean anything*.
#
# Let's look at how different beers have different IBU measurements.

# %% [markdown]
# ## What is the average IBU measurement across all beers?

# %%
df["IBUs"].mean()
# Out:
# 42.713167259786474

# %% [markdown]
# ## Draw the distribution of IBU measurements, but with
# 2326          Durango, CO                    American IPA  12 oz.   6.50%
# 2330         Missoula, MT                    American IPA  16 oz.   6.50%
# 2349          Durango, CO                    American IPA  12 oz.   6.80%
# 2369       Gig Harbor, WA  American Double / Imperial IPA  16 oz.   8.40%
# 2375       Woodbridge, CT  American Double / Imperial IPA  16 oz.   8.80%
# 2382          Ashland, OR                    American IPA  12 oz.   6.10%
# 2387          Lahaina, HI                    American IPA  12 oz.   6.20%
# 2394        Pottstown, PA                    American IPA  12 oz.   7.00%
# 2403  Brooklyn Center, MN  American Double / Imperial IPA  16 oz.   9.70%
# 2406  Brooklyn Center, MN                    American IPA  16 oz.   6.20%
# 2408    San Francisco, CA                    American IPA  12 oz.   7.00%
# 2410         Longmont, CO          Russian Imperial Stout  12 oz.   9.90%
# 2412         Longmont, CO  American Double / Imperial IPA  12 oz.   9.90%
# 2414         Longmont, CO  American Double / Imperial IPA  12 oz.   8.70%
# 2415         Longmont, CO         American Pale Ale (APA)  12 oz.   6.50%
#
#        IBUs   ABV2
# 6      68.0   8.00
# 7      80.0  12.50
# 14     68.0   7.60
# 17     65.0   6.00
# 21     80.0   7.20
# 22     65.0   6.70
# 24    100.0   8.00
# 25     85.0   7.50
# 27    100.0   8.00
# 46     75.0   9.50
# 59     65.0   6.50
# 62     72.0   5.80
# 68     90.0  12.00
# 69     75.0   7.20
# 79     90.0   6.40
# 89     90.0   8.50
# 93     80.0   6.20
# 110   100.0   5.00
# 123    70.0   7.00
# 149    68.0   8.20
# 168    70.0   5.90
# 170    82.0   7.00
# 178    75.0   7.10
# 182    90.0   8.50
# 186   115.0   7.50
# 192    69.0   6.30
# 218   115.0   9.90
# 226    75.0   7.50
# 229    65.0   6.30
# 239    67.0   5.20
# ...     ...    ...
# 2181   70.0   6.50
# 2182  120.0   8.00
# 2186   80.0   7.00
# 2218   90.0   7.50
# 2225   85.0   8.80
# 2228   97.0   7.40
# 2229   85.0   7.00
# 2234  103.0   9.30
# 2252   68.0   6.20
# 2257   80.0   6.50
# 2261   69.0   6.90
# 2267   65.0   6.80
# 2306   70.0   6.50
# 2313   69.0   6.30
# 2316   93.0   7.20
# 2326   65.0   6.50
# 2330   65.0   6.50
# 2349   65.0   6.80
# 2369   82.0   8.40
# 2375   85.0   8.80
# 2382   94.0   6.10
# 2387   65.0   6.20
# 2394  113.0   7.00
# 2403  120.0   9.70
# 2406   99.0   6.20
# 2408   65.0   7.00
# 2410   98.0   9.90
# 2412  100.0   9.90
# 2414   85.0   8.70
# 2415   65.0   6.50
#
# [346 rows x 8 columns]

# %% [markdown]
# ## List all of the beers with IBUs below the 25th percentile

# %%
df[df["IBUs"] < df["IBUs"].quantile(0.25)]
# Out:
#                                         Beer  \
# 2                                 Wall's End
# 12                                  Sho'nuff
# 13                               Bloody Show
# 18                            The Brown Note
# 19                               House Lager
# 20                              Leisure Time
# 30                                      Park
# 31                                 Westfalia
# 32                                       KSA
# 54                                   Sparkle
# 56                              Hotbox Brown
# 57                                      Gold
# 66                                Cafe Leche
# 67                    Damascene Apricot Sour
# 90                               Sex Panther
# Belgian IPA                            61.0
# English Barleywine                     60.0
# Rye Beer                               57.0
# Baltic Porter                          52.0
# English Strong Ale                     52.0
# American Double / Imperial Stout       51.0
# English India Pale Ale (IPA)           47.0
# American White IPA                     45.0
# American Pale Ale (APA)                44.0
# Extra Special / Strong Bitter (ESB)    41.0
# California Common / Steam Beer         41.0
# Old Ale                                40.0
# American Stout                         40.0
# Altbier                                36.5
# Foreign / Export Stout                 36.0
# Smoked Beer                            35.0
# Belgian Dark Ale                       35.0
# German Pilsener                        35.0
# Irish Dry Stout                        34.0
# Czech Pilsener                         33.0
#                                        ...
# Munich Dunkel Lager                    21.0
# English Brown Ale                      20.5
# American Blonde Ale                    20.0
# American Pale Wheat Ale                20.0
# Roggenbier                             20.0
# Pumpkin Ale                            20.0
# Keller Bier / Zwickel Bier             20.0
# Cream Ale                              20.0
# American Pale Lager                    18.5
# Munich Helles Lager                    18.0
# English Pale Mild Ale                  16.0
# Dunkelweizen                           16.0
# Other                                  16.0
# Witbier                                15.5
# Fruit / Vegetable Beer                 15.5
# Herbed / Spiced Beer                   15.0
# Hefeweizen                             15.0
# Light Lager                            12.0
# Gose                                   10.0
# American Adjunct Lager                  9.0
# Berliner Weissbier                      8.0
# American Malt Liquor                    NaN
# Braggot                                 NaN
# Cider                                   NaN
# Flanders Red Ale                        NaN
# Kristalweizen                           NaN
# Low Alcohol Beer                        NaN
# Mead                                    NaN
# Rauchbier                               NaN
# Shandy                                  NaN
# Name: IBUs, Length: 99, dtype: float64

# %%
df.groupby("Style")["IBUs"].median().sort_values(na_position="first").plot(kind="barh")
#can't get the figsize=(...) argument to work

# %% [markdown]
# ## Hmmmm, it looks like they are generally different styles. What are the most common 5 styles of high-IBU beer vs. low-IBU beer?
#
# You'll want to think about it in three pieces - finding the high IBU beers, then finding out what the most common styles are, then getting the top 5.

# %%
df[df["IBUs"] > df["IBUs"].quantile(0.75)]["Style"].value_counts().head(5)
#Listing the top 5 beers in the highest quantile
# Out:
# American IPA                      195
# American Double / Imperial IPA     72
# American Pale Ale (APA)            18
# American Black Ale                 15
# American Strong Ale                 9
# Name: Style, dtype: int64

# %%
df[df["IBUs"] < df["IBUs"].quantile(0.25)]["Style"].value_counts().head(5)
#Listing the top 5 beers in the lowest quantile
# Out:
# American Pale Wheat Ale    43
# American Blonde Ale        36
# Fruit / Vegetable Beer     28
# Hefeweizen                 21
# Witbier                    20
# Name: Style, dtype: int64

# %% [markdown]
# ## Get the average IBU of "Witbier", "Hefeweizen" and "American Pale Wheat Ale" styles (also draw a histogram)
#
# I want ONE measurement and ONE graph, not three separate ones. And 20 to 30 bins in the histogram, please.

# %%
Somebeers = df[(df["Style"] == "Witbier") | (df["Style"] == "Hefeweizen") | (df["Style"] == "American Pale Wheat Ale")]

# %%
Somebeers.groupby("Style")["IBUs"].mean()
# Out:
# Style
# American Pale Wheat Ale    20.688525
# Hefeweizen                 17.592593
# Witbier                    16.208333
# Name: IBUs, dtype: float64

# %%
Somebeers.hist(bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x09408DF0>]], dtype=object)

# %% [markdown]
# ## Get the average IBU of any style with "IPA" in it (also draw a histogram)

# %%
IPAs = df[df["Style"].notnull()]

# %%
IPAs = IPAs[IPAs["Style"].str.contains("IPA")]

# %%
IPAs["IBUs"].mean()
#the mean value is 72
# Out:
# 71.948979591836732

# %%
IPAs["IBUs"].hist(bins=30)

# %% [markdown]
# ## Plot those two histograms on top of one another

# %% [markdown]
# ## Compare the ABV of wheat beers vs. IPAs
