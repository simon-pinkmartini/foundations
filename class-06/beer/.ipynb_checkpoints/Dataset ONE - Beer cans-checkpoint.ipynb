# %% [markdown]
# # A dataset about cans of beer.
#
# Data from http://craftcans.com/

# %% [markdown]
# ## Do your importing and your setup

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Read in the file `craftcans.csv`, and look at the first first rows

# %%
df = pd.read_csv("craftcans.csv")

# %%
df.head(2)
# Out:
#             Beer            Brewery         Location               Style  \
# 0   Get Together  NorthGate Brewing  Minneapolis, MN        American IPA
# 1  Maggie's Leap  NorthGate Brewing  Minneapolis, MN  Milk / Sweet Stout
#
#      Size    ABV  IBUs
# 0  16 oz.  4.50%  50.0
# 1  16 oz.  4.90%  26.0

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?

# %%
df.shape #we have 2416 rows
# Out:
# (2416, 7)

# %%
df.dtypes #we have 7 columns, all text except "IBUs"
# Out:
# Beer         object
# Brewery      object
# Location     object
# Style        object
# Size         object
# ABV          object
# IBUs        float64
# dtype: object

# %% [markdown]
# # Checking out breweries
#
# Where does beer come from????

# %% [markdown]
# ## What are the top 10 producers of cans of beer?

# %%
df["Brewery"].value_counts().head(10) #the top brewery is "Brewery Vivant"
# Out:
# Brewery Vivant                62
# Oskar Blues Brewery           46
# Sun King Brewing Company      38
# Cigar City Brewing Company    25
# Sixpoint Craft Ales           24
# Hopworks Urban Brewery        23
# Stevens Point Brewery         22
# 21st Amendment Brewery        20
# Great Crescent Brewery        20
# Bonfire Brewing Company       19
# Name: Brewery, dtype: int64

# %% [markdown]
# ## What is the most common size of beer?
#
# The answer won't be pretty - we'll learn to clean it up in a week or two.

# %%
df["Size"].value_counts() 
#the entry format wasn't strictly followed. but from the values, safe to say that 12 oz. is most common size
# Out:
# 12 oz.               1507
# 16 oz.                814
# 24 oz.                 21
# 16 oz. Alumi-Tek®      15
# 19.2 oz.               14
# 12 oz                  14
# 16 oz                  12
# 32 oz.                  5
# 19.2                    1
# 12 ounce                1
# 12 OZ.                  1
# 24 oz. "Silo Can"       1
# 8.4 oz.                 1
# 16.9 oz.                1
# 12 & 16 oz.             1
# 12 oz. Slimline         1
# Name: Size, dtype: int64

# %% [markdown]
# ## What is the most common ABV? (alcohol by volume)

# %%
df["ABV"].value_counts().head(10)
#most common ABV-Value is 5.00%
# Out:
# 5.00%    215
# 5.50%    158
# 6.00%    125
# 6.50%    123
# 5.20%    107
# 7.00%     92
# 4.50%     89
# 4.80%     72
# 5.80%     66
# 5.60%     66
# Name: ABV, dtype: int64

# %% [markdown]
# ## Oh, weird, ABV isn't a number. Convert it to a number for me, please.
#
# It's going to take three steps:
#
# 1. List just the ABV of every row
# 2. Remove the % symbol
# 3. Convert it to a `float`
# 4. Save it into a new column. Or the same column, if you're feeling wild.
#
# Although it *also* turns out that there's some bad data in there. We'll need to clean that up, too.

# %%
import numpy as np

# %%
df["ABV2"] = df["ABV"].str.replace("?", "").str.replace("%", "").replace("", np.nan) #try cleaning in new col

# %%
df["ABV2"].value_counts().keys() #looks ok
# Out:
# Index(['5.00', '5.50', '6.00', '6.50', '5.20', '7.00', '4.50', '4.80', '5.80',
#        '5.60', '5.10', '5.30', '4.90', '6.20', '8.00', '4.70', '6.80', '5.70',
#        '5.40', '7.50', '4.20', '4.00', '6.30', '7.20', '9.90', '5.90', '6.90',
#        '4.60', '8.50', '6.70', '9.00', '8.20', '6.10', '6.40', '6.60', '7.10',
#        '7.30', '4.40', '3.90', '9.20', '7.70', '4.30', '8.70', '7.80', '9.50',
#        '4.10', '8.30', '7.40', '7.90', '3.80', '8.80', '3.50', '9.60', '9.30',
#        '9.70', '7.60', '8.10', '8.60', '3.70', '3.20', '8.40', '9.80', '9.10',
#        '8.90', '2.70', '0.10', '10.00', '12.00', '2.80', '10.40', '3.40',
#        '12.50', '9.40', '12.80'],
#       dtype='object')

# %%
df["ABV"] = df["ABV2"].astype(float) #convert back into old col

# %%
df.pop("ABV2") #now get rid of this
# Out:
# 0        4.50
# 1        4.90
# 2        4.80
# 3        6.00
# 4        6.00
# 5        5.60
# 6        8.00
# 7       12.50
# 8        7.70
# 9        4.20
# 10       5.00
# 11       6.60
# 12       4.00
# 13       5.50
# 14       7.60
# 15       5.10
# 16       6.50
# 17       6.00
# 18       5.00
# 19       5.20
# 20       4.80
# 21       7.20
# 22       6.70
# 23       4.90
# 24       8.00
# 25       7.50
# 26       6.00
# 27       8.00
# 28       6.30
# 29       5.80
#         ...
# 2386     5.70
# 2387     6.20
# 2388     4.90
# 2389     9.90
# 2390     6.20
# 2391     5.80
# 2392     5.20
# 2393     8.50
# 2394     7.00
# 2395     5.30
# 2396     5.60
# 2397     4.90
# 2398     5.10
# 2399     4.00
# 2400     5.50
# 2401     5.10
# 2402     5.10
# 2403     9.70
# 2404     5.10
# 2405     6.70
# 2406     6.20
# 2407     8.30
# 2408     7.00
# 2409     4.90
# 2410     9.90
# 2411     5.30
# 2412     9.90
# 2413     8.00
# 2414     8.70
# 2415     6.50
# ...

# %%
df.head()
# Out:
#             Beer            Brewery         Location               Style  \
# 0   Get Together  NorthGate Brewing  Minneapolis, MN        American IPA
# 1  Maggie's Leap  NorthGate Brewing  Minneapolis, MN  Milk / Sweet Stout
# 2     Wall's End  NorthGate Brewing  Minneapolis, MN   English Brown Ale
# 3        Pumpion  NorthGate Brewing  Minneapolis, MN         Pumpkin Ale
# 4     Stronghold  NorthGate Brewing  Minneapolis, MN     American Porter
#
#      Size  ABV  IBUs
# 0  16 oz.  4.5  50.0
# 1  16 oz.  4.9  26.0
# 2  16 oz.  4.8  19.0
# 3  16 oz.  6.0  38.0
# 4  16 oz.  6.0  25.0

# %%
df.dtypes #okay
# Out:
# Beer         object
# Brewery      object
# Location     object
# Style        object
# Size         object
# ABV         float64
# IBUs        float64
# dtype: object

# %% [markdown]
# # Looking at location
#
# Brooklyn used to produce 80% of the country's beer! Let's see if it's still true.

# %% [markdown]
# ## What are the top 10 cities in the US for canned craft beer?

# %%
df["Location"].value_counts().head(10)
#No! Grand Rapids is Number 1. Brooklyn only No. 8
# Out:
# Grand Rapids, MI    66
# Chicago, IL         55
# Portland, OR        52
# Indianapolis, IN    43
# San Diego, CA       42
# Boulder, CO         41
# Denver, CO          40
# Brooklyn, NY        38
# Seattle, WA         35
# Longmont, CO        33
# Name: Location, dtype: int64

# %% [markdown]
# ## List all of the beer from Brooklyn, NY

# %%
df[df["Location"] == "Brooklyn, NY"]
# Out:
#                                  Beer              Brewery      Location  \
# 115                            4Beans  Sixpoint Craft Ales  Brooklyn, NY
# 210                            Jammer  Sixpoint Craft Ales  Brooklyn, NY
# 246                           Abigale  Sixpoint Craft Ales  Brooklyn, NY
# 404                     Nomader Weiss    Evil Twin Brewing  Brooklyn, NY
# 421                               Rad  Sixpoint Craft Ales  Brooklyn, NY
# 439                      Molotov Lite    Evil Twin Brewing  Brooklyn, NY
# 588                           Bengali  Sixpoint Craft Ales  Brooklyn, NY
# 713                     Sensi Harvest  Sixpoint Craft Ales  Brooklyn, NY
# 969                            Hi-Res  Sixpoint Craft Ales  Brooklyn, NY
# 987             KelSo Nut Brown Lager   KelSo Beer Company  Brooklyn, NY
# 1057                    Global Warmer  Sixpoint Craft Ales  Brooklyn, NY
# 1074               Autumnation (2013)  Sixpoint Craft Ales  Brooklyn, NY
# ...

# %% [markdown]
# ## What brewery in Brooklyn puts out the most cans of beer?

# %%
df[df["Location"] == "Brooklyn, NY"]["Brewery"].value_counts()
#It's Sixpoint Craft Ales
# Out:
# Sixpoint Craft Ales    24
# Brooklyn Brewery        6
# Evil Twin Brewing       5
# KelSo Beer Company      3
# Name: Brewery, dtype: int64

# %% [markdown]
# ## What are the five most popular styles of beer produced by Sixpoint?

# %%
df[df["Brewery"] == "Sixpoint Craft Ales"]["Style"].value_counts().head(5)
# Out:
# American IPA                      4
# Cream Ale                         2
# American Double / Imperial IPA    2
# German Pilsener                   2
# Baltic Porter                     2
# Name: Style, dtype: int64

# %% [markdown]
# ## List all of the breweries in New York state. Then count them.

# %%
df[df["Location"].str[-2:] == "NY"]["Brewery"].value_counts()
# Out:
# Sixpoint Craft Ales              24
# Matt Brewing Company             13
# Brooklyn Brewery                  6
# Evil Twin Brewing                 5
# Butternuts Beer and Ale           4
# Blue Point Brewing Company        4
# The Bronx Brewery                 3
# KelSo Beer Company                3
# Bomb Beer Company                 2
# Chatham Brewing                   2
# Montauk Brewing Company           2
# Upstate Brewing Company           2
# Newburgh Brewing Company          1
# Southampton Publick House         1
# Dundee Brewing Company            1
# The Manhattan Brewing Company     1
# Name: Brewery, dtype: int64

# %%
len(df[df["Location"].str[-2:] == "NY"]["Brewery"].value_counts())
#There are 16 Breweries in NY State
# Out:
# 16

# %% [markdown]
# # Measuring International Bitterness Units
#
# IBU stands for [International Bitterness Unit](http://www.thebrewenthusiast.com/ibus/), and while a lot of places like to brag about having the most bitter beer (it's an American thing!), IBUs don't necessary *mean anything*.
#
# Let's look at how different beers have different IBU measurements.

# %% [markdown]
# ## What is the average IBU measurement across all beers?

# %%
df["IBUs"].mean()
# Out:
# 42.713167259786474

# %% [markdown]
# ## Draw the distribution of IBU measurements, but with *thirty* bins instead of the default of 10

# %%
df["IBUs"].hist(bins=30)

# %% [markdown]
# ## List all of the beers with IBUs above the 75th percentile

# %%
df[df["IBUs"] > df["IBUs"].quantile(0.75)]
# Out:
#                                    Beer                           Brewery  \
# 6                        Citra Ass Down         Against the Grain Brewery
# 7                        London Balling         Against the Grain Brewery
# 14                          Rico Sauvin         Against the Grain Brewery
# 17                         Pile of Face         Against the Grain Brewery
# 21                           Excess IPL          Jack's Abby Craft Lagers
# 22                       Hoponius Union          Jack's Abby Craft Lagers
# 24                       Habitus (2014)         Mike Hess Brewing Company
# 25                                Solis         Mike Hess Brewing Company
# 27                              Habitus         Mike Hess Brewing Company
# 46                  Yeti Imperial Stout      Great Divide Brewing Company
# 59    98 Problems (Cuz A Hop Ain't One)            Perrin Brewing Company
# 62                         Train Hopper       Witch's Hat Brewing Company
# ...

# %% [markdown]
# ## List all of the beers with IBUs below the 25th percentile

# %%
df[df["IBUs"] < df["IBUs"].quantile(0.25)]
# Out:
#                                         Beer  \
# 2                                 Wall's End
# 12                                  Sho'nuff
# 13                               Bloody Show
# 18                            The Brown Note
# 19                               House Lager
# 20                              Leisure Time
# 30                                      Park
# 31                                 Westfalia
# 32                                       KSA
# 54                                   Sparkle
# 56                              Hotbox Brown
# 57                                      Gold
# 66                                Cafe Leche
# 67                    Damascene Apricot Sour
# 90                               Sex Panther
# 102                           Vanilla Porter
# 105                                     Gose
# 106                          Vermont Pilsner
# 134                      Ginger Peach Saison
# 139                            Weissenheimer
# ...

# %% [markdown]
# ## List the median IBUs of each type of beer. Graph it.
#
# Put the highest at the top, and the nan ones at the bottom. I want a nice graph, too - don't let them all be squished together, either!

# %%
df.groupby("Style")["IBUs"].median().sort_values(ascending=False)
# Out:
# Style
# American Barleywine                    96.0
# Russian Imperial Stout                 94.0
# American Double / Imperial IPA         91.0
# American Double / Imperial Pilsner     85.0
# American Black Ale                     73.0
# Belgian Strong Dark Ale                72.0
# American Strong Ale                    70.0
# American IPA                           69.0
# English Stout                          66.0
# American India Pale Lager              65.0
# Belgian IPA                            61.0
# English Barleywine                     60.0
# Rye Beer                               57.0
# Baltic Porter                          52.0
# English Strong Ale                     52.0
# American Double / Imperial Stout       51.0
# English India Pale Ale (IPA)           47.0
# American White IPA                     45.0
# American Pale Ale (APA)                44.0
# Extra Special / Strong Bitter (ESB)    41.0
# California Common / Steam Beer         41.0
# ...

# %%
df.groupby("Style")["IBUs"].median().sort_values(na_position="first").plot(kind="barh")
#can't get the figsize=(...) argument to work

# %% [markdown]
# ## Hmmmm, it looks like they are generally different styles. What are the most common 5 styles of high-IBU beer vs. low-IBU beer?
#
# You'll want to think about it in three pieces - finding the high IBU beers, then finding out what the most common styles are, then getting the top 5.

# %%
df[df["IBUs"] > df["IBUs"].quantile(0.75)]["Style"].value_counts().head(5)
#Listing the top 5 beers in the highest quantile
# Out:
# American IPA                      195
# American Double / Imperial IPA     72
# American Pale Ale (APA)            18
# American Black Ale                 15
# American Strong Ale                 9
# Name: Style, dtype: int64

# %%
df[df["IBUs"] < df["IBUs"].quantile(0.25)]["Style"].value_counts().head(5)
#Listing the top 5 beers in the lowest quantile
# Out:
# American Pale Wheat Ale    43
# American Blonde Ale        36
# Fruit / Vegetable Beer     28
# Hefeweizen                 21
# Witbier                    20
# Name: Style, dtype: int64

# %% [markdown]
# ## Get the average IBU of "Witbier", "Hefeweizen" and "American Pale Wheat Ale" styles (also draw a histogram)
#
# I want ONE measurement and ONE graph, not three separate ones. And 20 to 30 bins in the histogram, please.

# %%
Somebeers = df[(df["Style"] == "Witbier") | (df["Style"] == "Hefeweizen") | (df["Style"] == "American Pale Wheat Ale")]

# %%
Somebeers.groupby("Style")["IBUs"].mean()
# Out:
# Style
# American Pale Wheat Ale    20.688525
# Hefeweizen                 17.592593
# Witbier                    16.208333
# Name: IBUs, dtype: float64

# %%
Somebeers["IBUs"].hist(bins=30)

# %% [markdown]
# ## Get the average IBU of any style with "IPA" in it (also draw a histogram)

# %%
IPAs = df[df["Style"].str.contains("IPA", na=False)]

# %%
IPAs["IBUs"].mean()
#the mean value is 72
# Out:
# 71.948979591836732

# %%
IPAs["IBUs"].hist(bins=30)

# %% [markdown]
# ## Plot those two histograms on top of one another

# %%
ax = Somebeers["IBUs"].hist(bins=30)
IPAs["IBUs"].hist(bins=30, ax=ax)

# %% [markdown]
# ## Compare the ABV of wheat beers vs. IPAs

# %%
Somebeers["ABV"].mean()
# Out:
# 5.0437158469945356

# %%
IPAs["ABV"].mean() #IPAs have a higher ABV than wheat beers on average
# Out:
# 6.8792857142857136

# %%
ax = Somebeers["ABV"].hist(bins=30) #showing histogram

# %%
IPAs["ABV"].hist(bins=30) #other histogram
